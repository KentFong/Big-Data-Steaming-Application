# %% [markdown]
# # Task 1 : MongoDB Data Model

# %% [markdown]
# ##### Based on the two data sets provided i.e. hotspot_historic.csv and climate_historic.csv, we have designed a suitable data model to support the efficient storing and querying of the two data sets in MongoDB. We know that the climate and fire data will be gathered in large quantities over the years whcih makes us think about a model which is easy to scale and yet have a distinguised event entities among different collections in database. We will be the reference model. As we observe that both "date" fields of the dataset are similar and can be compared, we have decided to join them based on that field when querying. A similar date for both datasets would imply that on that day with that particular climate report, there is a fire in that area.
#
# ##### The reason is such that although the datasets are relatively small, but given that MongoDB has a limit of 16MB of data size, other models such as embedding model might not be able to scale to such an large amount of data. Besides, by referencing, we save up data space as well when we avoid repetition of climate data when we embed only one hotspot object into the climate data. Our data model adresses the following: high scalability and  keep the information free from redundancies.
#
# ##### However, the only downside of our data model is that it increases the number of join query operations. We believe that analysis and query in a climate and hotspot data are performed only based on a small section of fields. This is similar to the array storage structure, which can significantly reduce data scanning and reduce the impact on query performance. Mongo DB is one of those databases with the table elimination feature that can greatly reduce the number of join operations.

# %% [markdown]
# ## Schema Creation

# %% [markdown]
# ##### We create the schema to ease with queries and also gives us an idea of how our model would look like.

# %%
# schema to validate the climate collection.
{
        "station": {
            "description": "Constant station ID"
        },
        "date": {
            "description": "Date in datetime format"
        },
        "air_temperature_celcius": {
            "description": "Temperature in int format"
        },
        "relative_humidity": {
            "description": "Humidity in int format"
        },
        "windspeed_knots": {
            "description": "Windspeed in int format"
        },
        "max_wind_speed": {
            "description": "Windspeed in int format"
        },
        "precipitation": {
            "description": "Precipitation in int format"
        },
        "precipitation_type": {
            "description": "Type in str format"
        },
        "GHI_w/m2": {
            "description": "int format"
        }
}
# Out:
# {'station': {'description': 'Constant station ID'},
#  'date': {'description': 'Date in datetime format'},
#  'air_temperature_celcius': {'description': 'Temperature in int format'},
#  'relative_humidity': {'description': 'Humidity in int format'},
#  'windspeed_knots': {'description': 'Windspeed in int format'},
#  'max_wind_speed': {'description': 'Windspeed in int format'},
#  'precipitation': {'description': 'Precipitation in int format'},
#  'precipitation_type': {'description': 'Type in str format'},
#  'GHI_w/m2': {'description': 'int format'}}

# %%
# schema to validate the hotspot collection.
{
        "latitude": {
            "description": "Latitude in int format"
        },
        "longitude": {
            "description": "Longitude in int format"
        },
        "datetime": {
            "description": "Date and time in datetime format"
        },
        "confidence": {
            "description": "Confidence in int format"
        },
        "date": {
            "description": "Date in date format"
        },
        "surface_temperature_celcius": {
            "description": "Temperature in int format"
        }
}
# Out:
# {'latitude': {'description': 'Latitude in int format'},
#  'longitude': {'description': 'Longitude in int format'},
#  'datetime': {'description': 'Date and time in datetime format'},
#  'confidence': {'description': 'Confidence in int format'},
#  'date': {'description': 'Date in date format'},
#  'surface_temperature_celcius': {'description': 'Temperature in int format'}}

# %% [markdown]
# ##### An example of the MongoDB model for climate data and hotspots data can be seen below, respectively.

# %% [markdown]
# {<br>
#  '_id': ObjectId('628f22a0500536bc72322b80'), <br>
#  'station': 948700, <br>
#  'date': datetime.datetime(2020, 12, 31, 0, 0), <br>
#  'air_temperature_celcius': 19, <br>
#  'relative_humidity': 56.8, <br>
#  'windspeed_knots': 7.9, <br>
#  'max_wind_speed': 11.1, <br>
#  'precipitation ': 0.0, <br>
#  'GHI_w/m2': 154, <br>
#  'precipitation_type': 'I' <br> }

# %% [markdown]
# {<br>'_id': ObjectId('628961b952e0577c296e7dc4'), <br>
#  'latitude': -37.966,<br>
#  'longitude': 145.05100000000002,<br>
#  'datetime': datetime.datetime(2021, 12, 27, 4, 16, 51),<br>
#  'confidence': 78,<br>
#  'date': datetime.datetime(2021, 12, 27, 0, 0),<br>
#  'surface_temperature_celcius': 68<br>}

# %% [markdown]
# # Task 2. Querying MongoDB using PyMongo

# %% [markdown]
# ## 1. Reading data from csv to MongoDB.

# %%
# import the following libraries to perform this task.
from pymongo import MongoClient # access mongoDb using python.
import datetime 
import pandas as pd
from datetime import datetime
import dateutil.parser
import pymongo
from pprint import pprint

# %%
# instantiating mongo client.
client = pymongo.MongoClient()

# instantiating the database
db = client.fit3182_db

# %%
# instantiating the collections in the created database.
climate_collection = db.climate # collection named "climate"
hotspot_collection = db.hotspot # collection names "hotspot"

# %%
# read the csv file into respective variables.
climate = pd.read_csv("climate_historic.csv")
hotspot = pd.read_csv("hotspot_historic.csv")

# %%
# emptying the collections to prevent repetitive data
climate_collection.drop()
hotspot_collection.drop()

# %%
# transform the climate date to datetime format. We also preprocess the precipitation data into two columns, precipitation value and precipitation type.
climate["date"] = pd.to_datetime(climate["date"], format="%d/%m/%y")
climate["precipitation_type"] = climate["precipitation "].str[-1]
climate["precipitation "] = climate["precipitation "].str.slice(0,5) # precipitation type is at the 5th string index
climate["precipitation "] = pd.to_numeric(climate["precipitation "])

# %%
# transform the hotspot date and hotspot time to datetime format.
hotspot["datetime"] = pd.to_datetime(hotspot["datetime"], format="%Y-%m-%dT%H:%M:%S")
hotspot["date"] = pd.to_datetime(hotspot["date"], format="%d/%m/%Y")

# %%
# instantiate the csv as dictionaries (json format)
climate_dict = climate.to_dict(orient = "records")
hotspot_dict = hotspot.to_dict(orient = "records")

# %%
climate_collection.insert_many(climate_dict)

# %%
hotspot_collection.insert_many(hotspot_dict)

# %%
#finds one object from the climate collection
climate_collection.find_one()
# Out:
# {'_id': ObjectId('6290c48ca64bd561823ffcc7'),
#  'station': 948700,
#  'date': datetime.datetime(2020, 12, 31, 0, 0),
#  'air_temperature_celcius': 19,
#  'relative_humidity': 56.8,
#  'windspeed_knots': 7.9,
#  'max_wind_speed': 11.1,
#  'precipitation ': 0.0,
#  'GHI_w/m2': 154,
#  'precipitation_type': 'I'}

# %%
hotspot_collection.find_one()
# Out:
# {'_id': ObjectId('6290c48da64bd561823ffe35'),
#  'latitude': -37.966,
#  'longitude': 145.05100000000002,
#  'datetime': datetime.datetime(2021, 12, 27, 4, 16, 51),
#  'confidence': 78,
#  'date': datetime.datetime(2021, 12, 27, 0, 0),
#  'surface_temperature_celcius': 68}

# %% [markdown]
# ## 2. PyMongo Queries

# %% [markdown]
# ##### a. Find climate data on 12th December 2021.

# %%
results = climate_collection.find({'date': datetime(2021, 12, 12)}) #matches the desired date 
for x in results:
    pprint(x)
# Out:
# {'GHI_w/m2': 156,
#  '_id': ObjectId('6290c48ca64bd561823ffe20'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 12, 12, 0, 0),
#  'max_wind_speed': 12.0,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %% [markdown]
# ##### b. Find the latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.

# %%
# find the surface_temperature_celcius using gte and lte, and then show required fields, sort by temperature for easy viewing
results = hotspot_collection.find({"surface_temperature_celcius":{"$gte" : 65,"$lte":100}}, 
                               {"latitude": 1, "longitude":1,"confidence": 1,"surface_temperature_celcius":1
                                }).sort([("surface_temperature_celcius",1)])


for x in results:
    pprint(x)
# Out:
# {'_id': ObjectId('6290c48da64bd561823ffe6a'),
#  'confidence': 100,
#  'latitude': -37.641999999999996,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffe8d'),
#  'confidence': 87,
#  'latitude': -37.861999999999995,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffeac'),
#  'confidence': 90,
#  'latitude': -37.330999999999996,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffeeb'),
#  'confidence': 88,
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fff0a'),
#  'confidence': 100,
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fff2a'),
#  'confidence': 100,
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fff59'),
#  'confidence': 89,
#  'latitude': -38.3998,
#  'longitude': 147.064,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fffd9'),
#  'confidence': 89,
#  'latitude': -38.4792,
#  'longitude': 146.3081,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400022'),
#  'confidence': 89,
#  'latitude': -36.5661,
#  'longitude': 142.2956,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400040'),
#  'confidence': 89,
#  'latitude': -35.4666,
#  'longitude': 142.0749,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400095'),
#  'confidence': 89,
#  'latitude': -36.7218,
#  'longitude': 141.6411,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824001d2'),
#  'confidence': 89,
#  'latitude': -36.4143,
#  'longitude': 143.27200000000002,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824002a3'),
#  'confidence': 89,
#  'latitude': -37.876,
#  'longitude': 143.7804,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824002e1'),
#  'confidence': 89,
#  'latitude': -36.2618,
#  'longitude': 141.8783,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400329'),
#  'confidence': 89,
#  'latitude': -37.0959,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824003f5'),
#  'confidence': 89,
#  'latitude': -34.9023,
#  'longitude': 142.0557,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400464'),
#  'confidence': 89,
#  'latitude': -36.73,
#  'longitude': 143.935,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824004a5'),
#  'confidence': 89,
#  'latitude': -36.0295,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824004d3'),
#  'confidence': 89,
#  'latitude': -38.1561,
#  'longitude': 143.7846,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824004ed'),
#  'confidence': 89,
#  'latitude': -35.7642,
#  'longitude': 143.3321,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400558'),
#  'confidence': 89,
#  'latitude': -36.1441,
#  'longitude': 145.2221,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824005bc'),
#  'confidence': 89,
#  'latitude': -37.88,
#  'longitude': 143.7233,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd5618240069b'),
#  'confidence': 84,
#  'latitude': -37.5816,
#  'longitude': 148.5862,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824006a1'),
#  'confidence': 77,
#  'latitude': -37.8062,
#  'longitude': 143.3598,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824006ac'),
#  'confidence': 89,
#  'latitude': -36.9902,
#  'longitude': 141.879,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824006ad'),
#  'confidence': 89,
#  'latitude': -37.745,
#  'longitude': 142.993,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824006b8'),
#  'confidence': 89,
#  'latitude': -34.3943,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824006d8'),
#  'confidence': 88,
#  'latitude': -37.7746,
#  'longitude': 148.3673,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd5618240072f'),
#  'confidence': 89,
#  'latitude': -37.4471,
#  'longitude': 147.6331,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400735'),
#  'confidence': 89,
#  'latitude': -37.4449,
#  'longitude': 147.6594,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400766'),
#  'confidence': 89,
#  'latitude': -35.4255,
#  'longitude': 143.6306,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824007d9'),
#  'confidence': 89,
#  'latitude': -36.1556,
#  'longitude': 141.5904,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561824007dc'),
#  'confidence': 89,
#  'latitude': -35.7647,
#  'longitude': 142.0858,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd5618240084f'),
#  'confidence': 82,
#  'latitude': -37.8973,
#  'longitude': 143.4754,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400885'),
#  'confidence': 89,
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffe43'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561823fff1f'),
#  'confidence': 73,
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240000e'),
#  'confidence': 90,
#  'latitude': -36.7032,
#  'longitude': 144.0992,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240002e'),
#  'confidence': 85,
#  'latitude': -36.5023,
#  'longitude': 143.6038,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824001cb'),
#  'confidence': 89,
#  'latitude': -36.5116,
#  'longitude': 144.562,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824002ab'),
#  'confidence': 80,
#  'latitude': -36.1559,
#  'longitude': 141.8102,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824002d5'),
#  'confidence': 90,
#  'latitude': -37.6267,
#  'longitude': 142.9993,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824002e3'),
#  'confidence': 90,
#  'latitude': -36.6828,
#  'longitude': 144.784,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824002e6'),
#  'confidence': 89,
#  'latitude': -37.4843,
#  'longitude': 143.0592,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400347'),
#  'confidence': 84,
#  'latitude': -38.0423,
#  'longitude': 146.4048,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824003fc'),
#  'confidence': 89,
#  'latitude': -37.2609,
#  'longitude': 141.7999,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240045b'),
#  'confidence': 78,
#  'latitude': -35.9326,
#  'longitude': 141.958,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824004b9'),
#  'confidence': 90,
#  'latitude': -35.1949,
#  'longitude': 141.0622,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824004bf'),
#  'confidence': 89,
#  'latitude': -35.8071,
#  'longitude': 142.7318,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824004d5'),
#  'confidence': 90,
#  'latitude': -37.8185,
#  'longitude': 142.5609,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400505'),
#  'confidence': 90,
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400510'),
#  'confidence': 90,
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400545'),
#  'confidence': 90,
#  'latitude': -36.5399,
#  'longitude': 144.678,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240066e'),
#  'confidence': 90,
#  'latitude': -36.7165,
#  'longitude': 142.6155,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240069d'),
#  'confidence': 76,
#  'latitude': -37.7966,
#  'longitude': 142.3196,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824006cc'),
#  'confidence': 90,
#  'latitude': -36.6384,
#  'longitude': 142.4075,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400732'),
#  'confidence': 90,
#  'latitude': -37.7835,
#  'longitude': 148.4138,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240074c'),
#  'confidence': 85,
#  'latitude': -36.111,
#  'longitude': 145.124,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240074d'),
#  'confidence': 90,
#  'latitude': -36.1615,
#  'longitude': 141.8728,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240076a'),
#  'confidence': 85,
#  'latitude': -35.4533,
#  'longitude': 143.2029,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824007bc'),
#  'confidence': 89,
#  'latitude': -37.7446,
#  'longitude': 143.4085,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561824007c9'),
#  'confidence': 90,
#  'latitude': -35.7657,
#  'longitude': 142.0906,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400860'),
#  'confidence': 90,
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561823ffe38'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561823ffebd'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561823fff9a'),
#  'confidence': 90,
#  'latitude': -36.4325,
#  'longitude': 144.3142,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240003c'),
#  'confidence': 90,
#  'latitude': -38.0372,
#  'longitude': 146.0616,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd56182400092'),
#  'confidence': 90,
#  'latitude': -36.2911,
#  'longitude': 141.1664,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd56182400204'),
#  'confidence': 90,
#  'latitude': -36.3435,
#  'longitude': 141.5513,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd56182400224'),
#  'confidence': 90,
#  'latitude': -36.094,
#  'longitude': 145.7646,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240027e'),
#  'confidence': 90,
#  'latitude': -36.1303,
#  'longitude': 146.3606,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd56182400314'),
#  'confidence': 90,
#  'latitude': -36.7101,
#  'longitude': 142.3865,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240037d'),
#  'confidence': 90,
#  'latitude': -37.7756,
#  'longitude': 143.1388,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240042c'),
#  'confidence': 90,
#  'latitude': -37.1349,
#  'longitude': 141.9491,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561824004f2'),
#  'confidence': 90,
#  'latitude': -36.429,
#  'longitude': 141.5759,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240051c'),
#  'confidence': 90,
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240054b'),
#  'confidence': 90,
#  'latitude': -36.7903,
#  'longitude': 141.618,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd56182400568'),
#  'confidence': 90,
#  'latitude': -36.782,
#  'longitude': 141.8851,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561824005ec'),
#  'confidence': 90,
#  'latitude': -36.2857,
#  'longitude': 141.3467,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561824005f7'),
#  'confidence': 90,
#  'latitude': -36.5532,
#  'longitude': 142.5349,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561824006ca'),
#  'confidence': 90,
#  'latitude': -37.5788,
#  'longitude': 148.592,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561824006f6'),
#  'confidence': 90,
#  'latitude': -36.0387,
#  'longitude': 145.6787,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240074a'),
#  'confidence': 90,
#  'latitude': -35.4033,
#  'longitude': 143.267,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240078b'),
#  'confidence': 79,
#  'latitude': -36.883,
#  'longitude': 142.1637,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd56182400880'),
#  'confidence': 90,
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561823ffe35'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.05100000000002,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823ffec9'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823fff7b'),
#  'confidence': 91,
#  'latitude': -36.3774,
#  'longitude': 143.7079,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823fffa0'),
#  'confidence': 91,
#  'latitude': -36.7801,
#  'longitude': 142.7151,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823fffd0'),
#  'confidence': 91,
#  'latitude': -36.7746,
#  'longitude': 146.6642,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd5618240007e'),
#  'confidence': 90,
#  'latitude': -35.6871,
#  'longitude': 143.5235,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561824000b5'),
#  'confidence': 84,
#  'latitude': -37.8323,
#  'longitude': 147.2232,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd5618240012f'),
#  'confidence': 91,
#  'latitude': -36.4168,
#  'longitude': 141.6939,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400142'),
#  'confidence': 91,
#  'latitude': -35.6138,
#  'longitude': 143.8666,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400188'),
#  'confidence': 91,
#  'latitude': -36.5061,
#  'longitude': 144.5675,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400198'),
#  'confidence': 91,
#  'latitude': -36.3635,
#  'longitude': 142.2809,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561824001bf'),
#  'confidence': 91,
#  'latitude': -36.7751,
#  'longitude': 145.1696,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561824002d0'),
#  'confidence': 91,
#  'latitude': -37.6397,
#  'longitude': 142.5968,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400328'),
#  'confidence': 77,
#  'latitude': -36.7101,
#  'longitude': 142.981,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400386'),
#  'confidence': 91,
#  'latitude': -37.7171,
#  'longitude': 142.9505,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400423'),
#  'confidence': 91,
#  'latitude': -37.0782,
#  'longitude': 145.3625,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd5618240043c'),
#  'confidence': 91,
#  'latitude': -36.7651,
#  'longitude': 143.5801,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400535'),
#  'confidence': 91,
#  'latitude': -36.3487,
#  'longitude': 145.5315,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400572'),
#  'confidence': 90,
#  'latitude': -36.5568,
#  'longitude': 144.0538,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561824005a2'),
#  'confidence': 91,
#  'latitude': -37.6171,
#  'longitude': 142.9426,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561824005f1'),
#  'confidence': 91,
#  'latitude': -36.4449,
#  'longitude': 140.9836,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561824006c7'),
#  'confidence': 86,
#  'latitude': -37.5814,
#  'longitude': 148.5777,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561824006e1'),
#  'confidence': 91,
#  'latitude': -37.3803,
#  'longitude': 145.611,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd5618240074b'),
#  'confidence': 64,
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400843'),
#  'confidence': 91,
#  'latitude': -38.0674,
#  'longitude': 142.965,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400882'),
#  'confidence': 90,
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd5618240088f'),
#  'confidence': 80,
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823ffe99'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823fff1d'),
#  'confidence': 64,
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823fff62'),
#  'confidence': 91,
#  'latitude': -37.8644,
#  'longitude': 143.4263,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823fff9d'),
#  'confidence': 91,
#  'latitude': -36.7685,
#  'longitude': 142.7134,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd56182400078'),
#  'confidence': 91,
#  'latitude': -36.5541,
#  'longitude': 144.1321,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd5618240007b'),
#  'confidence': 91,
#  'latitude': -35.6819,
#  'longitude': 143.5275,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd5618240009e'),
#  'confidence': 91,
#  'latitude': -36.3153,
#  'longitude': 140.9789,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd5618240019b'),
#  'confidence': 91,
#  'latitude': -36.6564,
#  'longitude': 142.8615,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561824001c3'),
#  'confidence': 91,
#  'latitude': -36.3961,
#  'longitude': 140.9781,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561824001fa'),
#  'confidence': 92,
#  'latitude': -36.7593,
#  'longitude': 142.895,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd56182400300'),
#  'confidence': 91,
#  'latitude': -37.6964,
#  'longitude': 142.8583,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561824003fb'),
#  'confidence': 91,
#  'latitude': -36.2637,
#  'longitude': 145.3649,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd56182400463'),
#  'confidence': 91,
#  'latitude': -36.6892,
#  'longitude': 145.2775,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561824004b5'),
#  'confidence': 91,
#  'latitude': -36.1748,
#  'longitude': 145.7582,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561824005ad'),
#  'confidence': 91,
#  'latitude': -37.4611,
#  'longitude': 144.9371,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561824005d1'),
#  'confidence': 91,
#  'latitude': -35.6453,
#  'longitude': 142.387,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd56182400662'),
#  'confidence': 91,
#  'latitude': -35.2363,
#  'longitude': 143.0004,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd5618240069c'),
#  'confidence': 92,
#  'latitude': -36.6334,
#  'longitude': 142.2244,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561824006c5'),
#  'confidence': 91,
#  'latitude': -36.031,
#  'longitude': 145.6824,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823ffe4f'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561823ffff4'),
#  'confidence': 92,
#  'latitude': -36.9396,
#  'longitude': 143.1462,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd5618240009a'),
#  'confidence': 92,
#  'latitude': -36.3207,
#  'longitude': 140.9737,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824000c8'),
#  'confidence': 92,
#  'latitude': -37.4463,
#  'longitude': 142.7829,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824001cd'),
#  'confidence': 92,
#  'latitude': -36.803000000000004,
#  'longitude': 142.9261,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824001dd'),
#  'confidence': 92,
#  'latitude': -36.882,
#  'longitude': 142.7108,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824002a7'),
#  'confidence': 87,
#  'latitude': -37.9091,
#  'longitude': 143.5105,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400306'),
#  'confidence': 92,
#  'latitude': -37.9284,
#  'longitude': 143.108,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400393'),
#  'confidence': 92,
#  'latitude': -37.6498,
#  'longitude': 142.5997,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824003be'),
#  'confidence': 92,
#  'latitude': -36.5828,
#  'longitude': 144.5775,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400405'),
#  'confidence': 92,
#  'latitude': -36.2652,
#  'longitude': 145.3769,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824004a1'),
#  'confidence': 92,
#  'latitude': -36.1924,
#  'longitude': 143.1716,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400512'),
#  'confidence': 92,
#  'latitude': -36.9364,
#  'longitude': 143.4996,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824005ee'),
#  'confidence': 92,
#  'latitude': -36.0749,
#  'longitude': 143.4058,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd5618240061b'),
#  'confidence': 92,
#  'latitude': -37.4033,
#  'longitude': 143.6884,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400696'),
#  'confidence': 92,
#  'latitude': -37.2063,
#  'longitude': 147.4713,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400697'),
#  'confidence': 92,
#  'latitude': -37.2082,
#  'longitude': 147.4368,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561824006b1'),
#  'confidence': 92,
#  'latitude': -36.0157,
#  'longitude': 145.9414,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400844'),
#  'confidence': 92,
#  'latitude': -38.0715,
#  'longitude': 142.9591,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd5618240086b'),
#  'confidence': 92,
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561823ffe5a'),
#  'confidence': 100,
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561823ffe6b'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561824000db'),
#  'confidence': 92,
#  'latitude': -38.2391,
#  'longitude': 142.82,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd5618240014e'),
#  'confidence': 92,
#  'latitude': -37.7889,
#  'longitude': 143.1324,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd5618240016f'),
#  'confidence': 92,
#  'latitude': -36.663000000000004,
#  'longitude': 142.8567,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561824001f1'),
#  'confidence': 87,
#  'latitude': -38.0148,
#  'longitude': 146.5413,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561824004f3'),
#  'confidence': 92,
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd56182400524'),
#  'confidence': 92,
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd56182400571'),
#  'confidence': 92,
#  'latitude': -36.5586,
#  'longitude': 144.0423,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561824005f8'),
#  'confidence': 92,
#  'latitude': -36.1367,
#  'longitude': 145.2071,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd56182400635'),
#  'confidence': 93,
#  'latitude': -36.6823,
#  'longitude': 142.5024,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561824006c0'),
#  'confidence': 81,
#  'latitude': -36.0844,
#  'longitude': 141.4934,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561824006e5'),
#  'confidence': 92,
#  'latitude': -37.8161,
#  'longitude': 142.9286,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd56182400775'),
#  'confidence': 66,
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd56182400808'),
#  'confidence': 92,
#  'latitude': -36.4557,
#  'longitude': 142.2434,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd5618240088d'),
#  'confidence': 84,
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561823fff20'),
#  'confidence': 61,
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400125'),
#  'confidence': 93,
#  'latitude': -36.2306,
#  'longitude': 143.6408,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824001ad'),
#  'confidence': 93,
#  'latitude': -36.6657,
#  'longitude': 143.1675,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824001e4'),
#  'confidence': 93,
#  'latitude': -37.5135,
#  'longitude': 142.7238,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd5618240020a'),
#  'confidence': 93,
#  'latitude': -36.6942,
#  'longitude': 143.8021,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400249'),
#  'confidence': 70,
#  'latitude': -36.9303,
#  'longitude': 143.1034,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd5618240026a'),
#  'confidence': 93,
#  'latitude': -36.9111,
#  'longitude': 142.692,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd5618240027b'),
#  'confidence': 93,
#  'latitude': -37.769,
#  'longitude': 147.94,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824002c3'),
#  'confidence': 93,
#  'latitude': -36.1964,
#  'longitude': 144.5217,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824002de'),
#  'confidence': 93,
#  'latitude': -36.5871,
#  'longitude': 144.4958,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400365'),
#  'confidence': 93,
#  'latitude': -37.9157,
#  'longitude': 143.3544,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824003d8'),
#  'confidence': 93,
#  'latitude': -36.8879,
#  'longitude': 141.6647,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824003e7'),
#  'confidence': 93,
#  'latitude': -36.663000000000004,
#  'longitude': 141.3038,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd5618240049e'),
#  'confidence': 93,
#  'latitude': -36.1941,
#  'longitude': 143.1604,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400507'),
#  'confidence': 93,
#  'latitude': -36.5243,
#  'longitude': 142.0839,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824006b6'),
#  'confidence': 93,
#  'latitude': -37.5888,
#  'longitude': 148.5949,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824006ff'),
#  'confidence': 86,
#  'latitude': -36.6986,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400729'),
#  'confidence': 93,
#  'latitude': -37.3165,
#  'longitude': 147.4932,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400788'),
#  'confidence': 93,
#  'latitude': -37.0769,
#  'longitude': 141.042,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824007a2'),
#  'confidence': 93,
#  'latitude': -37.7465,
#  'longitude': 143.3806,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561824007d3'),
#  'confidence': 93,
#  'latitude': -37.3046,
#  'longitude': 143.5448,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400881'),
#  'confidence': 93,
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561823ffe3f'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561823ffe46'),
#  'confidence': 93,
#  'latitude': -38.056999999999995,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561823ffe86'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.35399999999998,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561823fffee'),
#  'confidence': 93,
#  'latitude': -37.4984,
#  'longitude': 142.9739,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd5618240008c'),
#  'confidence': 93,
#  'latitude': -37.4671,
#  'longitude': 145.9962,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400179'),
#  'confidence': 94,
#  'latitude': -37.6982,
#  'longitude': 143.0549,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561824001ef'),
#  'confidence': 88,
#  'latitude': -38.0132,
#  'longitude': 146.5269,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400212'),
#  'confidence': 93,
#  'latitude': -36.4046,
#  'longitude': 141.1534,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400222'),
#  'confidence': 93,
#  'latitude': -36.388000000000005,
#  'longitude': 141.8309,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561824002ff'),
#  'confidence': 94,
#  'latitude': -37.7274,
#  'longitude': 142.9536,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400319'),
#  'confidence': 93,
#  'latitude': -38.1693,
#  'longitude': 143.0466,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400350'),
#  'confidence': 94,
#  'latitude': -38.1224,
#  'longitude': 143.7553,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400387'),
#  'confidence': 94,
#  'latitude': -37.7236,
#  'longitude': 142.947,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561824003e5'),
#  'confidence': 93,
#  'latitude': -36.4899,
#  'longitude': 142.2805,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561824003ff'),
#  'confidence': 93,
#  'latitude': -36.91,
#  'longitude': 141.0704,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400476'),
#  'confidence': 93,
#  'latitude': -36.8238,
#  'longitude': 143.5724,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561824004ae'),
#  'confidence': 93,
#  'latitude': -35.0616,
#  'longitude': 141.4417,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561824005ea'),
#  'confidence': 94,
#  'latitude': -36.3313,
#  'longitude': 141.0017,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd5618240063d'),
#  'confidence': 93,
#  'latitude': -36.4489,
#  'longitude': 144.7685,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd5618240080b'),
#  'confidence': 93,
#  'latitude': -36.8099,
#  'longitude': 142.72799999999998,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400842'),
#  'confidence': 71,
#  'latitude': -37.522,
#  'longitude': 143.3874,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400893'),
#  'confidence': 94,
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd5618240003d'),
#  'confidence': 94,
#  'latitude': -38.049,
#  'longitude': 146.0513,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400048'),
#  'confidence': 94,
#  'latitude': -36.2775,
#  'longitude': 146.1026,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400102'),
#  'confidence': 94,
#  'latitude': -37.4357,
#  'longitude': 142.7813,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd561824001ca'),
#  'confidence': 94,
#  'latitude': -37.7609,
#  'longitude': 143.1633,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd561824001e5'),
#  'confidence': 94,
#  'latitude': -36.2121,
#  'longitude': 144.6885,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd561824002a4'),
#  'confidence': 88,
#  'latitude': -36.1546,
#  'longitude': 141.8146,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400429'),
#  'confidence': 94,
#  'latitude': -36.3966,
#  'longitude': 141.406,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd5618240065f'),
#  'confidence': 67,
#  'latitude': -37.34,
#  'longitude': 149.3668,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400810'),
#  'confidence': 94,
#  'latitude': -36.7806,
#  'longitude': 141.5597,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400874'),
#  'confidence': 94,
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd561823ffe41'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400071'),
#  'confidence': 94,
#  'latitude': -36.0828,
#  'longitude': 145.873,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400098'),
#  'confidence': 94,
#  'latitude': -36.4179,
#  'longitude': 144.2924,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd561824003f3'),
#  'confidence': 94,
#  'latitude': -36.092,
#  'longitude': 141.7306,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400530'),
#  'confidence': 94,
#  'latitude': -36.2933,
#  'longitude': 141.36,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400561'),
#  'confidence': 94,
#  'latitude': -36.4816,
#  'longitude': 141.6635,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd561824005c3'),
#  'confidence': 95,
#  'latitude': -35.0706,
#  'longitude': 141.4435,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd561824005dd'),
#  'confidence': 95,
#  'latitude': -37.8906,
#  'longitude': 146.2035,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd5618240060d'),
#  'confidence': 94,
#  'latitude': -37.5812,
#  'longitude': 142.7374,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400619'),
#  'confidence': 95,
#  'latitude': -37.4028,
#  'longitude': 143.6932,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400851'),
#  'confidence': 95,
#  'latitude': -37.7805,
#  'longitude': 143.5003,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400884'),
#  'confidence': 95,
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400889'),
#  'confidence': 94,
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd561823ffe76'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561823fff1e'),
#  'confidence': 86,
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400043'),
#  'confidence': 95,
#  'latitude': -36.0396,
#  'longitude': 141.7183,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561824000d3'),
#  'confidence': 95,
#  'latitude': -37.6854,
#  'longitude': 143.4543,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400145'),
#  'confidence': 95,
#  'latitude': -36.0885,
#  'longitude': 145.0359,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400156'),
#  'confidence': 95,
#  'latitude': -37.9509,
#  'longitude': 143.9599,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd5618240017c'),
#  'confidence': 95,
#  'latitude': -36.7187,
#  'longitude': 143.805,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400230'),
#  'confidence': 95,
#  'latitude': -36.6537,
#  'longitude': 143.8781,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400238'),
#  'confidence': 95,
#  'latitude': -38.1987,
#  'longitude': 147.0666,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd5618240024f'),
#  'confidence': 95,
#  'latitude': -36.3014,
#  'longitude': 143.203,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561824003d3'),
#  'confidence': 95,
#  'latitude': -36.6995,
#  'longitude': 142.97799999999998,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd5618240058c'),
#  'confidence': 95,
#  'latitude': -36.8681,
#  'longitude': 143.5186,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561824005ff'),
#  'confidence': 95,
#  'latitude': -36.1418,
#  'longitude': 144.0261,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400698'),
#  'confidence': 95,
#  'latitude': -37.224000000000004,
#  'longitude': 147.4347,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561824006a5'),
#  'confidence': 90,
#  'latitude': -36.1104,
#  'longitude': 145.9829,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd5618240072d'),
#  'confidence': 95,
#  'latitude': -37.3158,
#  'longitude': 147.4986,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400737'),
#  'confidence': 95,
#  'latitude': -37.4323,
#  'longitude': 147.6583,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400760'),
#  'confidence': 90,
#  'latitude': -36.1122,
#  'longitude': 142.1491,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561824007d6'),
#  'confidence': 95,
#  'latitude': -36.4312,
#  'longitude': 141.2064,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400809'),
#  'confidence': 95,
#  'latitude': -36.8009,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561823ffea4'),
#  'confidence': 96,
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823ffed1'),
#  'confidence': 96,
#  'latitude': -38.126999999999995,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823fff1b'),
#  'confidence': 68,
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823ffffb'),
#  'confidence': 96,
#  'latitude': -36.3387,
#  'longitude': 141.7542,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd5618240001d'),
#  'confidence': 96,
#  'latitude': -36.3402,
#  'longitude': 141.7429,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400054'),
#  'confidence': 95,
#  'latitude': -36.3254,
#  'longitude': 144.3638,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561824000a5'),
#  'confidence': 96,
#  'latitude': -36.8094,
#  'longitude': 142.8885,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400150'),
#  'confidence': 95,
#  'latitude': -36.6139,
#  'longitude': 143.501,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd5618240024b'),
#  'confidence': 83,
#  'latitude': -36.3195,
#  'longitude': 146.0601,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd5618240031b'),
#  'confidence': 95,
#  'latitude': -36.7128,
#  'longitude': 142.3717,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400407'),
#  'confidence': 95,
#  'latitude': -36.738,
#  'longitude': 142.1177,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd5618240041f'),
#  'confidence': 95,
#  'latitude': -36.5199,
#  'longitude': 144.7311,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400504'),
#  'confidence': 95,
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561824005da'),
#  'confidence': 95,
#  'latitude': -37.9152,
#  'longitude': 145.8808,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400613'),
#  'confidence': 95,
#  'latitude': -37.8247,
#  'longitude': 143.6243,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561824006e0'),
#  'confidence': 96,
#  'latitude': -37.7542,
#  'longitude': 142.9949,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561824007a7'),
#  'confidence': 95,
#  'latitude': -37.8072,
#  'longitude': 145.9738,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400854'),
#  'confidence': 95,
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823fff28'),
#  'confidence': 62,
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561823fff92'),
#  'confidence': 96,
#  'latitude': -36.1002,
#  'longitude': 142.3405,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561823fffd2'),
#  'confidence': 96,
#  'latitude': -36.8359,
#  'longitude': 146.6448,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561823fffef'),
#  'confidence': 96,
#  'latitude': -37.253,
#  'longitude': 144.3681,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400030'),
#  'confidence': 90,
#  'latitude': -36.8616,
#  'longitude': 142.8025,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400096'),
#  'confidence': 84,
#  'latitude': -37.3656,
#  'longitude': 141.3903,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561824000da'),
#  'confidence': 96,
#  'latitude': -38.0866,
#  'longitude': 143.9534,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561824000fb'),
#  'confidence': 96,
#  'latitude': -36.3438,
#  'longitude': 141.5832,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400146'),
#  'confidence': 96,
#  'latitude': -36.3193,
#  'longitude': 145.9162,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd5618240016d'),
#  'confidence': 96,
#  'latitude': -38.0933,
#  'longitude': 143.9824,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561824001f3'),
#  'confidence': 96,
#  'latitude': -37.8429,
#  'longitude': 147.2691,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd5618240025f'),
#  'confidence': 86,
#  'latitude': -37.6775,
#  'longitude': 148.5131,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400290'),
#  'confidence': 96,
#  'latitude': -36.5847,
#  'longitude': 145.1968,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd5618240037a'),
#  'confidence': 96,
#  'latitude': -37.7935,
#  'longitude': 143.1606,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd5618240046c'),
#  'confidence': 96,
#  'latitude': -36.1898,
#  'longitude': 145.0922,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400494'),
#  'confidence': 84,
#  'latitude': -36.7531,
#  'longitude': 141.3253,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd5618240049d'),
#  'confidence': 96,
#  'latitude': -36.9498,
#  'longitude': 142.2012,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400694'),
#  'confidence': 96,
#  'latitude': -37.222,
#  'longitude': 147.4689,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561824006dd'),
#  'confidence': 83,
#  'latitude': -37.803000000000004,
#  'longitude': 142.3151,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400769'),
#  'confidence': 96,
#  'latitude': -36.1955,
#  'longitude': 145.914,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400786'),
#  'confidence': 96,
#  'latitude': -36.6006,
#  'longitude': 141.9657,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561824007a8'),
#  'confidence': 96,
#  'latitude': -37.3704,
#  'longitude': 145.8942,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561823fff30'),
#  'confidence': 100,
#  'latitude': -37.400999999999996,
#  'longitude': 148.067,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400093'),
#  'confidence': 96,
#  'latitude': -36.2842,
#  'longitude': 141.1741,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400217'),
#  'confidence': 96,
#  'latitude': -36.0594,
#  'longitude': 141.5907,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd5618240033f'),
#  'confidence': 96,
#  'latitude': -36.6787,
#  'longitude': 144.8042,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd561824003bf'),
#  'confidence': 96,
#  'latitude': -36.5987,
#  'longitude': 144.4995,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400472'),
#  'confidence': 96,
#  'latitude': -36.8298,
#  'longitude': 143.4483,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400492'),
#  'confidence': 84,
#  'latitude': -36.7432,
#  'longitude': 141.3296,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400557'),
#  'confidence': 97,
#  'latitude': -36.1067,
#  'longitude': 143.7948,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd561824005fe'),
#  'confidence': 96,
#  'latitude': -36.1518,
#  'longitude': 144.0233,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd5618240077a'),
#  'confidence': 97,
#  'latitude': -36.1925,
#  'longitude': 145.93,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd5618240085d'),
#  'confidence': 96,
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400888'),
#  'confidence': 96,
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd561823ffe82'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.30700000000002,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561823ffea7'),
#  'confidence': 97,
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561823fff7d'),
#  'confidence': 97,
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400163'),
#  'confidence': 97,
#  'latitude': -36.6224,
#  'longitude': 143.5092,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561824001ea'),
#  'confidence': 97,
#  'latitude': -36.2206,
#  'longitude': 144.6856,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561824004c1'),
#  'confidence': 97,
#  'latitude': -36.7787,
#  'longitude': 141.4449,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400521'),
#  'confidence': 97,
#  'latitude': -37.0669,
#  'longitude': 141.0556,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400548'),
#  'confidence': 97,
#  'latitude': -36.8158,
#  'longitude': 142.6229,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400575'),
#  'confidence': 91,
#  'latitude': -36.4612,
#  'longitude': 144.7775,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400583'),
#  'confidence': 97,
#  'latitude': -36.601,
#  'longitude': 144.6378,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561824005a9'),
#  'confidence': 84,
#  'latitude': -37.7587,
#  'longitude': 142.8521,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd5618240066c'),
#  'confidence': 66,
#  'latitude': -37.3493,
#  'longitude': 149.3691,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400815'),
#  'confidence': 97,
#  'latitude': -37.0924,
#  'longitude': 141.89700000000002,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd5618240081d'),
#  'confidence': 97,
#  'latitude': -37.9452,
#  'longitude': 143.5834,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400872'),
#  'confidence': 97,
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400894'),
#  'confidence': 97,
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561824000a0'),
#  'confidence': 97,
#  'latitude': -36.4169,
#  'longitude': 144.2994,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('6290c48da64bd5618240013a'),
#  'confidence': 97,
#  'latitude': -36.4211,
#  'longitude': 141.6875,
# ...
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd561824001d6'),
#  'confidence': 99,
#  'latitude': -36.7153,
#  'longitude': 143.8226,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd56182400270'),
#  'confidence': 99,
#  'latitude': -37.5115,
#  'longitude': 143.14,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd561824003e4'),
#  'confidence': 100,
#  'latitude': -35.8768,
#  'longitude': 145.4627,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd561824006f8'),
#  'confidence': 94,
#  'latitude': -36.6349,
#  'longitude': 142.2125,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd561824007d1'),
#  'confidence': 99,
#  'latitude': -37.7236,
#  'longitude': 143.3995,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd56182400823'),
#  'confidence': 99,
#  'latitude': -34.351,
#  'longitude': 141.6567,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd561823ffe80'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd561823ffecd'),
#  'confidence': 100,
#  'latitude': -37.294000000000004,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd561823fff57'),
#  'confidence': 94,
#  'latitude': -37.4796,
#  'longitude': 141.9403,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd5618240000d'),
#  'confidence': 100,
#  'latitude': -36.345,
#  'longitude': 143.4256,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd56182400199'),
#  'confidence': 100,
#  'latitude': -36.664,
#  'longitude': 142.8802,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd561824001f2'),
#  'confidence': 100,
#  'latitude': -37.8412,
#  'longitude': 147.2536,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd5618240032d'),
#  'confidence': 100,
#  'latitude': -37.9594,
#  'longitude': 143.5638,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd5618240049a'),
#  'confidence': 100,
#  'latitude': -36.7957,
#  'longitude': 143.9652,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd56182400563'),
#  'confidence': 100,
#  'latitude': -36.0837,
#  'longitude': 144.2448,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd561823fff19'),
#  'confidence': 100,
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd561823fff7c'),
#  'confidence': 100,
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd561824001dc'),
#  'confidence': 100,
#  'latitude': -36.7309,
#  'longitude': 142.3633,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd561824002af'),
#  'confidence': 100,
#  'latitude': -37.9071,
#  'longitude': 143.53799999999998,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd561824004af'),
#  'confidence': 100,
#  'latitude': -36.3999,
#  'longitude': 144.737,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd56182400514'),
#  'confidence': 100,
#  'latitude': -37.3847,
#  'longitude': 142.8935,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd5618240069f'),
#  'confidence': 100,
#  'latitude': -37.8429,
#  'longitude': 143.8366,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd56182400720'),
#  'confidence': 87,
#  'latitude': -37.6387,
#  'longitude': 142.9032,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd561823fff7e'),
#  'confidence': 100,
#  'latitude': -36.3799,
#  'longitude': 143.7149,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd561824000de'),
#  'confidence': 100,
#  'latitude': -38.5123,
#  'longitude': 146.4007,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd5618240017f'),
#  'confidence': 100,
#  'latitude': -36.7742,
#  'longitude': 145.1991,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd56182400389'),
#  'confidence': 100,
#  'latitude': -37.7002,
#  'longitude': 142.9562,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd561824004ac'),
#  'confidence': 100,
#  'latitude': -37.0761,
#  'longitude': 141.0574,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd56182400533'),
#  'confidence': 100,
#  'latitude': -37.4591,
#  'longitude': 144.9492,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd56182400693'),
#  'confidence': 100,
#  'latitude': -37.2168,
#  'longitude': 147.4748,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd5618240070a'),
#  'confidence': 94,
#  'latitude': -38.0052,
#  'longitude': 142.6179,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd561824007b7'),
#  'confidence': 100,
#  'latitude': -37.383,
#  'longitude': 145.9089,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd56182400845'),
#  'confidence': 100,
#  'latitude': -38.0693,
#  'longitude': 142.9722,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd561823ffeea'),
#  'confidence': 100,
#  'latitude': -37.461999999999996,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd561823fffde'),
#  'confidence': 100,
#  'latitude': -37.9047,
#  'longitude': 141.0945,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd5618240004f'),
#  'confidence': 100,
#  'latitude': -38.0361,
#  'longitude': 146.0567,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd5618240005d'),
#  'confidence': 100,
#  'latitude': -36.1532,
#  'longitude': 143.5527,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd5618240014a'),
#  'confidence': 100,
#  'latitude': -36.0682,
#  'longitude': 146.0602,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd56182400254'),
#  'confidence': 87,
#  'latitude': -36.3332,
#  'longitude': 145.8594,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd56182400475'),
#  'confidence': 100,
#  'latitude': -36.6615,
#  'longitude': 144.6014,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd561824004f7'),
#  'confidence': 100,
#  'latitude': -37.0899,
#  'longitude': 141.0238,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd56182400596'),
#  'confidence': 100,
#  'latitude': -37.1999,
#  'longitude': 143.8231,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd561824005f6'),
#  'confidence': 100,
#  'latitude': -36.3972,
#  'longitude': 141.6041,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd561824007b1'),
#  'confidence': 100,
#  'latitude': -37.2988,
#  'longitude': 143.5487,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd56182400829'),
#  'confidence': 100,
#  'latitude': -37.5012,
#  'longitude': 142.5853,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd5618240020d'),
#  'confidence': 100,
#  'latitude': -36.3459,
#  'longitude': 141.5586,
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('6290c48da64bd561824005c4'),
#  'confidence': 100,
#  'latitude': -38.0795,
#  'longitude': 143.2449,
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('6290c48da64bd56182400867'),
#  'confidence': 100,
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('6290c48da64bd5618240051d'),
#  'confidence': 100,
#  'latitude': -36.4125,
#  'longitude': 143.1189,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('6290c48da64bd561824005c7'),
#  'confidence': 100,
#  'latitude': -35.1857,
#  'longitude': 141.0604,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('6290c48da64bd561824005d6'),
#  'confidence': 100,
#  'latitude': -36.4409,
#  'longitude': 141.6948,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('6290c48da64bd561824005e6'),
#  'confidence': 100,
#  'latitude': -35.8182,
#  'longitude': 143.8739,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('6290c48da64bd56182400738'),
#  'confidence': 100,
#  'latitude': -37.4343,
#  'longitude': 147.6327,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('6290c48da64bd5618240078c'),
#  'confidence': 87,
#  'latitude': -36.0973,
#  'longitude': 143.4279,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('6290c48da64bd561823ffea3'),
#  'confidence': 100,
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561823fffd8'),
#  'confidence': 100,
#  'latitude': -38.4349,
#  'longitude': 146.3122,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd56182400065'),
#  'confidence': 100,
#  'latitude': -36.0077,
#  'longitude': 141.7747,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561824001d9'),
#  'confidence': 100,
#  'latitude': -36.8791,
#  'longitude': 142.7261,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561824002b8'),
#  'confidence': 100,
#  'latitude': -37.5043,
#  'longitude': 146.3299,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd56182400355'),
#  'confidence': 94,
#  'latitude': -38.0792,
#  'longitude': 143.7361,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd56182400466'),
#  'confidence': 100,
#  'latitude': -36.8283,
#  'longitude': 143.4605,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561824004e8'),
#  'confidence': 100,
#  'latitude': -36.1771,
#  'longitude': 145.7451,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd56182400578'),
#  'confidence': 100,
#  'latitude': -36.7089,
#  'longitude': 143.3518,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561824005d0'),
#  'confidence': 100,
#  'latitude': -35.6469,
#  'longitude': 142.376,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561824005d9'),
#  'confidence': 100,
#  'latitude': -37.9174,
#  'longitude': 145.8678,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561824007a9'),
#  'confidence': 100,
#  'latitude': -37.297,
#  'longitude': 143.5753,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd56182400009'),
#  'confidence': 100,
#  'latitude': -36.3433,
#  'longitude': 143.4369,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('6290c48da64bd56182400218'),
#  'confidence': 100,
#  'latitude': -36.0576,
#  'longitude': 141.6122,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('6290c48da64bd56182400236'),
#  'confidence': 100,
#  'latitude': -38.1917,
#  'longitude': 147.0745,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('6290c48da64bd5618240024d'),
#  'confidence': 100,
#  'latitude': -36.5854,
#  'longitude': 143.0462,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('6290c48da64bd5618240030a'),
#  'confidence': 100,
#  'latitude': -37.5701,
#  'longitude': 142.6497,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('6290c48da64bd56182400664'),
#  'confidence': 100,
#  'latitude': -35.2378,
#  'longitude': 142.9864,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('6290c48da64bd56182400083'),
#  'confidence': 100,
#  'latitude': -36.1506,
#  'longitude': 143.5671,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd5618240018c'),
#  'confidence': 100,
#  'latitude': -36.4035,
#  'longitude': 140.9935,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd561824002b7'),
#  'confidence': 100,
#  'latitude': -37.5027,
#  'longitude': 146.347,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd561824004eb'),
#  'confidence': 100,
#  'latitude': -38.027,
#  'longitude': 142.3844,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd5618240051b'),
#  'confidence': 100,
#  'latitude': -35.6374,
#  'longitude': 142.3787,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd5618240069e'),
#  'confidence': 100,
#  'latitude': -35.805,
#  'longitude': 142.1326,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd561824006d7'),
#  'confidence': 100,
#  'latitude': -36.9034,
#  'longitude': 141.0013,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd56182400763'),
#  'confidence': 100,
#  'latitude': -37.3735,
#  'longitude': 145.8384,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('6290c48da64bd561824001f6'),
#  'confidence': 100,
#  'latitude': -36.5454,
#  'longitude': 144.7402,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('6290c48da64bd5618240039a'),
#  'confidence': 100,
#  'latitude': -37.4352,
#  'longitude': 143.1444,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('6290c48da64bd561824004bc'),
#  'confidence': 100,
#  'latitude': -36.91,
#  'longitude': 141.2705,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('6290c48da64bd561824005e9'),
#  'confidence': 100,
#  'latitude': -37.9246,
#  'longitude': 146.2464,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('6290c48da64bd561824006d1'),
#  'confidence': 94,
#  'latitude': -35.811,
#  'longitude': 142.1403,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('6290c48da64bd561824007a0'),
#  'confidence': 87,
#  'latitude': -37.3735,
#  'longitude': 145.886,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('6290c48da64bd5618240049f'),
#  'confidence': 100,
#  'latitude': -36.4142,
#  'longitude': 143.1077,
#  'surface_temperature_celcius': 97}
# {'_id': ObjectId('6290c48da64bd56182400549'),
#  'confidence': 100,
#  'latitude': -36.4518,
#  'longitude': 144.7752,
#  'surface_temperature_celcius': 97}
# {'_id': ObjectId('6290c48da64bd561824006a3'),
#  'confidence': 100,
#  'latitude': -36.9918,
#  'longitude': 141.8667,
#  'surface_temperature_celcius': 97}
# {'_id': ObjectId('6290c48da64bd561824007c4'),
#  'confidence': 87,
#  'latitude': -37.7974,
#  'longitude': 145.9535,
#  'surface_temperature_celcius': 97}
# {'_id': ObjectId('6290c48da64bd56182400059'),
#  'confidence': 100,
#  'latitude': -36.0816,
#  'longitude': 145.859,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd561824001c5'),
#  'confidence': 100,
#  'latitude': -36.7708,
#  'longitude': 145.1908,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd561824002b5'),
#  'confidence': 100,
#  'latitude': -37.3902,
#  'longitude': 148.2955,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd56182400397'),
#  'confidence': 100,
#  'latitude': -37.5728,
#  'longitude': 142.6348,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd5618240060f'),
#  'confidence': 100,
#  'latitude': -37.5949,
#  'longitude': 142.6857,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd5618240062b'),
#  'confidence': 100,
#  'latitude': -37.8249,
#  'longitude': 143.6174,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd56182400796'),
#  'confidence': 100,
#  'latitude': -36.1819,
#  'longitude': 145.9269,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd561824007b6'),
#  'confidence': 100,
#  'latitude': -37.3025,
#  'longitude': 143.5714,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd56182400890'),
#  'confidence': 85,
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd5618240024c'),
#  'confidence': 100,
#  'latitude': -36.5839,
#  'longitude': 143.0588,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd5618240048b'),
#  'confidence': 75,
#  'latitude': -36.7499,
#  'longitude': 141.3006,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd561824005b7'),
#  'confidence': 100,
#  'latitude': -38.0254,
#  'longitude': 142.3959,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd561824006a6'),
#  'confidence': 100,
#  'latitude': -37.782,
#  'longitude': 148.3844,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd56182400856'),
#  'confidence': 100,
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd5618240088e'),
#  'confidence': 100,
#  'latitude': -37.4229,
#  'longitude': 147.02700000000002,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd56182400489'),
#  'confidence': 100,
#  'latitude': -36.1988,
#  'longitude': 145.0941,
#  'surface_temperature_celcius': 100}
# {'_id': ObjectId('6290c48da64bd561824006fe'),
#  'confidence': 100,
#  'latitude': -36.9018,
#  'longitude': 141.0146,
#  'surface_temperature_celcius': 100}

# %% [markdown]
# ##### c. Find date, surface temperature (°C), air temperature (°C), relative humidity and max wind speed on 15th and 16th of December 2021

# %%
# join the two datasets to show fields from both data
# use match and or to find the two desired dates, and project only necessary information
result = db.climate.aggregate([
    {
    "$lookup":{
        "from": "hotspot",
        "localField": "date",
        "foreignField": "date",
        "as":"hotspots",
        }
    },
    {
    "$match" : {"$or":[{"date": datetime(2021, 12, 15)},{"date":datetime(2021, 12, 16)}]}
    },
    {
    "$project" : {"date":1,"air_temperature_celcius":1,"relative_humidity":1,"max_wind_speed":1,"hotspots":{"surface_temperature_celcius":1}}  
    }
    ])
for x in result:
    pprint(x)
# pprint([x for x in result])
# Out:
# {'_id': ObjectId('6290c48ca64bd561823ffe23'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 42},
#               {'surface_temperature_celcius': 36},
#               {'surface_temperature_celcius': 38},
#               {'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'_id': ObjectId('6290c48ca64bd561823ffe24'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 43},
#               {'surface_temperature_celcius': 33},
#               {'surface_temperature_celcius': 54},
#               {'surface_temperature_celcius': 73},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 75},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 66},
#               {'surface_temperature_celcius': 56},
#               {'surface_temperature_celcius': 60},
#               {'surface_temperature_celcius': 73},
#               {'surface_temperature_celcius': 48},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 64},
#               {'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %% [markdown]
# ##### d. Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
# join based on date, then match the confidence between 80 and 100
# project necessary fields
result = db.hotspot.aggregate([{
    "$lookup":
    {
        "from": "climate",
        "localField": "date",
        "foreignField": "date",
        "as":"climate",
    }},
    {
    "$match" : {"confidence":{"$gte": 80, "$lte": 100}}
    },
    {
    "$project" : {"datetime": 1,
                "surface_temperature_celcius":1,"confidence":1,
                "climate":{"air_temperature_celcius":1}}  
    }
    ])
for x in result:
    pprint(x)
# pprint([x for x in result])
# Out:
# {'_id': ObjectId('6290c48da64bd561823ffe36'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd561823ffe38'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 12, 27, 0, 2, 14),
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561823ffe39'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 12, 25, 4, 29, 8),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe3c'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 12, 16, 15, 38, 39),
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd561823ffe3f'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 35, 13),
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561823ffe40'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 58),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffe41'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 58),
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd561823ffe43'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 57),
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd561823ffe46'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 12, 16, 0, 21, 12),
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561823ffe48'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 12, 16, 0, 21, 11),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffe49'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 12, 16, 0, 20, 53),
#  'surface_temperature_celcius': 64}
# {'_id': ObjectId('6290c48da64bd561823ffe4b'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 12, 15, 13, 17, 17),
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffe4f'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 12, 14, 4, 47, 25),
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561823ffe50'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 12, 13, 4, 4, 19),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823ffe54'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 34),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823ffe55'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 34),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe56'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 33),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823ffe57'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 33),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823ffe59'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 44),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe5a'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 44),
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561823ffe5b'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 43),
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823ffe5e'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd561823ffe61'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe63'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('6290c48da64bd561823ffe67'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('6290c48da64bd561823ffe68'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffe69'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffe6a'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffe6b'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 14),
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd561823ffe6c'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 35),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffe6e'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('6290c48da64bd561823ffe6f'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd561823ffe70'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823ffe71'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd561823ffe74'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823ffe75'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd561823ffe76'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561823ffe77'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823ffe79'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffe7d'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffe80'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd561823ffe82'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561823ffe83'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('6290c48da64bd561823ffe85'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 23, 4, 28, 59),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823ffe86'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 11, 23, 4, 28, 59),
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561823ffe8a'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 22, 3, 46),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffe8b'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 11, 22, 3, 46),
#  'surface_temperature_celcius': 64}
# {'_id': ObjectId('6290c48da64bd561823ffe8c'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 11, 21, 0, 27, 21),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffe8d'),
#  'climate': [{'air_temperature_celcius': 28}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 14, 4, 35, 4),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffe90'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 13, 3, 52, 15),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823ffe91'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 13, 3, 52, 14),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd561823ffe99'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 11, 12, 0, 33, 15),
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823ffe9b'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 11, 11, 13, 30, 8),
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('6290c48da64bd561823ffe9c'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 11, 13, 30, 8),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffe9d'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 11, 11, 4, 4, 25),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823ffea1'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffea3'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561823ffea4'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823ffea6'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 44),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd561823ffea7'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 44),
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561823ffeaa'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 11, 5, 4, 41, 34),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823ffeac'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 11, 5, 4, 41, 19),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffead'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 11, 5, 4, 41, 19),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd561823ffeae'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 10, 28, 3, 52, 17),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823ffeb1'),
#  'climate': [{'air_temperature_celcius': 22}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 10, 27, 4, 47, 31),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823ffeb5'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 26, 13, 30, 31),
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823ffeb6'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 26, 13, 30, 31),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd561823ffebb'),
#  'climate': [{'air_temperature_celcius': 12}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 10, 21, 1, 9, 55),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffebd'),
#  'climate': [{'air_temperature_celcius': 12}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 10, 21, 1, 9, 54),
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561823ffebe'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 10, 20, 4, 41, 19),
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('6290c48da64bd561823ffebf'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 20, 4, 41, 19),
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd561823ffec4'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 10, 18, 0, 39, 2),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffec5'),
#  'climate': [{'air_temperature_celcius': 26}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 18, 0, 39, 2),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823ffec7'),
#  'climate': [{'air_temperature_celcius': 22}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 10, 17, 13, 36, 12),
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd561823ffec9'),
#  'climate': [{'air_temperature_celcius': 22}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 10, 17, 4, 10, 45),
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823ffecb'),
#  'climate': [{'air_temperature_celcius': 22}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 17, 4, 10, 32),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffecd'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 15, 4, 23, 1),
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd561823ffece'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 10, 15, 4, 23, 1),
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('6290c48da64bd561823ffed1'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 10, 10, 4, 4, 19),
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823ffed5'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 10, 7, 12, 59, 33),
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffed9'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41, 2),
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('6290c48da64bd561823ffeda'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('6290c48da64bd561823ffedb'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffedc'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823ffede'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 10, 3, 13, 23, 43),
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffee3'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd561823ffee4'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823ffee5'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('6290c48da64bd561823ffee6'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffee7'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd561823ffeea'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd561823ffeeb'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823ffeec'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823ffef1'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 10, 2, 4, 53, 10),
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd561823ffef3'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 10, 2, 4, 53, 9),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823ffef7'),
#  'climate': [{'air_temperature_celcius': 12}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 1, 15, 13, 56),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffefa'),
#  'climate': [{'air_temperature_celcius': 12}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 10, 1, 4, 10, 28),
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823ffefb'),
#  'climate': [{'air_temperature_celcius': 12}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 10, 1, 4, 10, 28),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823ffeff'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 9, 29, 4, 22, 31),
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('6290c48da64bd561823fff01'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 9, 27, 4, 35, 36),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823fff02'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 27, 4, 35, 36),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823fff0a'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fff0d'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd561823fff0e'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823fff11'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 45),
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd561823fff12'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 45),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823fff13'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 10),
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('6290c48da64bd561823fff15'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('6290c48da64bd561823fff16'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823fff17'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823fff18'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 7),
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd561823fff19'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 19),
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd561823fff1e'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd561823fff22'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 4),
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823fff25'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 23, 23, 50, 44),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823fff29'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823fff2a'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fff2b'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823fff2c'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823fff2d'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd561823fff2f'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('6290c48da64bd561823fff30'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd561823fff32'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 13),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823fff34'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 11),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823fff35'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 11),
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd561823fff3f'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 9, 20, 4, 29, 3),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823fff40'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 20, 4, 29, 3),
#  'surface_temperature_celcius': 112}
# {'_id': ObjectId('6290c48da64bd561823fff42'),
#  'climate': [{'air_temperature_celcius': 14}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 9, 20, 4, 28, 45),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823fff43'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 9, 10, 4, 0),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823fff44'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 9, 10, 3, 53),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823fff45'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 10, 3, 50, 30),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823fff46'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 9, 10, 3, 50, 10),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823fff4d'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 8, 13, 5, 8),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd561823fff4f'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 8, 13, 5, 5, 10),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd561823fff54'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 8, 13, 5, 2, 30),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823fff57'),
#  'climate': [{'air_temperature_celcius': 5}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 8, 2, 3, 45, 40),
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd561823fff59'),
#  'climate': [{'air_temperature_celcius': 7}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 8, 1, 0, 20, 30),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fff5b'),
#  'climate': [{'air_temperature_celcius': 7}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 7, 31, 13, 21),
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('6290c48da64bd561823fff5c'),
#  'climate': [{'air_temperature_celcius': 7}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 7, 31, 13, 21),
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd561823fff61'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 7, 6, 4, 8),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823fff62'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 7, 6, 4, 2),
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823fff66'),
#  'climate': [{'air_temperature_celcius': 6}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29, 18),
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823fff67'),
#  'climate': [{'air_temperature_celcius': 6}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29, 18),
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823fff6a'),
#  'climate': [{'air_temperature_celcius': 6}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823fff6b'),
#  'climate': [{'air_temperature_celcius': 6}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823fff74'),
#  'climate': [{'air_temperature_celcius': 5}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823fff77'),
#  'climate': [{'air_temperature_celcius': 5}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823fff7b'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823fff7c'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('6290c48da64bd561823fff7d'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd561823fff7e'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd561823fff84'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 6, 14, 4, 43),
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('6290c48da64bd561823fff8b'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 6, 9, 4, 23, 20),
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823fff8c'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 6, 9, 4, 23, 16),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823fff8f'),
#  'climate': [{'air_temperature_celcius': 8}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 35, 50),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823fff92'),
#  'climate': [{'air_temperature_celcius': 8}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 33, 50),
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561823fff93'),
#  'climate': [{'air_temperature_celcius': 8}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823fff96'),
#  'climate': [{'air_temperature_celcius': 8}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823fff99'),
#  'climate': [{'air_temperature_celcius': 8}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823fff9a'),
#  'climate': [{'air_temperature_celcius': 8}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd561823fff9c'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 8, 20),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd561823fff9d'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 8, 10),
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823fffa0'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 2, 10),
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823fffa1'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 2, 10),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823fffad'),
#  'climate': [{'air_temperature_celcius': 12}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 6, 2, 4, 14, 10),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd561823fffae'),
#  'climate': [{'air_temperature_celcius': 12}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 6, 2, 4, 14, 10),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd561823fffb2'),
#  'climate': [{'air_temperature_celcius': 11}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 6, 1, 5, 9, 20),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd561823fffb6'),
#  'climate': [{'air_temperature_celcius': 13}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 26, 4, 8, 10),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823fffbb'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 23, 0, 58),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823fffbe'),
#  'climate': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 23, 0, 54, 50),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823fffc0'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 43, 30),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd561823fffc6'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 34, 10),
#  'surface_temperature_celcius': 101}
# {'_id': ObjectId('6290c48da64bd561823fffd0'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd561823fffd2'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561823fffd5'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('6290c48da64bd561823fffd8'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd561823fffd9'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd561823fffda'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 22, 0, 15),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd561823fffde'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 22, 0, 13),
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd561823fffdf'),
#  'climate': [{'air_temperature_celcius': 17}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 22, 0, 13),
#  'surface_temperature_celcius': 64}
# {'_id': ObjectId('6290c48da64bd561823fffee'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 34, 30),
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd561823fffef'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 34, 30),
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd561823ffff3'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 33),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd561823ffff4'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 33),
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd561823ffff9'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'surface_temperature_celcius': 101}
# {'_id': ObjectId('6290c48da64bd561823ffffa'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823ffffb'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 31, 20),
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823ffffc'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 31, 10),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd561823ffffd'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 30),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823ffffe'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 50),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd561823fffff'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 50),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd56182400009'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28),
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('6290c48da64bd5618240000c'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd5618240000d'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28),
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('6290c48da64bd5618240000e'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 27, 50),
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd5618240001c'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd5618240001d'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400021'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd56182400022'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400024'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 111}
# {'_id': ObjectId('6290c48da64bd56182400028'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd5618240002c'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd5618240002e'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400030'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('6290c48da64bd56182400033'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd56182400036'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400039'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd5618240003a'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('6290c48da64bd5618240003c'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd5618240003d'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd5618240003e'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 110}
# {'_id': ObjectId('6290c48da64bd56182400040'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400043'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('6290c48da64bd56182400047'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd56182400048'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400049'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd5618240004f'),
#  'climate': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 0, 12, 10),
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd56182400052'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 45, 40),
#  'surface_temperature_celcius': 102}
# {'_id': ObjectId('6290c48da64bd56182400054'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 43, 30),
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400059'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 41, 50),
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd5618240005c'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 20),
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('6290c48da64bd5618240005d'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 10),
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd5618240005f'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 39, 50),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400060'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 39, 30),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd56182400063'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 39),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd56182400065'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 50),
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('6290c48da64bd56182400067'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd56182400069'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd5618240006c'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd5618240006d'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd5618240006e'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd5618240006f'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd56182400070'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd56182400071'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400073'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 113}
# {'_id': ObjectId('6290c48da64bd56182400077'),
#  'climate': [{'air_temperature_celcius': 9}],
#  'confidence': 82,
# ...
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 50),
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd5618240080f'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 20),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd56182400810'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400813'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('6290c48da64bd56182400814'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd56182400815'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400818'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd5618240081a'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd5618240081b'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd5618240081d'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27, 40),
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd5618240081e'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27, 20),
#  'surface_temperature_celcius': 107}
# {'_id': ObjectId('6290c48da64bd56182400821'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27, 10),
#  'surface_temperature_celcius': 108}
# {'_id': ObjectId('6290c48da64bd56182400822'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400823'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27),
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('6290c48da64bd56182400826'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400827'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd56182400828'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd56182400829'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('6290c48da64bd5618240082c'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd5618240082d'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('6290c48da64bd5618240082e'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd5618240082f'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd56182400830'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd56182400831'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd56182400835'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('6290c48da64bd56182400837'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd56182400839'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd5618240083d'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 43, 20),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd5618240083f'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 40, 50),
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd56182400841'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 50),
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd56182400843'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400844'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd56182400845'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('6290c48da64bd56182400846'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400847'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd56182400849'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd5618240084f'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 59, 50),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400850'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 58, 10),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd56182400851'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 58, 10),
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400852'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd56182400853'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 111}
# {'_id': ObjectId('6290c48da64bd56182400854'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd56182400856'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 56, 40),
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd5618240085b'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 50),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd5618240085d'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400860'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 36),
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('6290c48da64bd56182400866'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33),
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('6290c48da64bd56182400867'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('6290c48da64bd56182400868'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd5618240086a'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 113}
# {'_id': ObjectId('6290c48da64bd5618240086b'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('6290c48da64bd5618240086c'),
#  'climate': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 106}
# {'_id': ObjectId('6290c48da64bd56182400871'),
#  'climate': [{'air_temperature_celcius': 21}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 18, 3, 50, 50),
#  'surface_temperature_celcius': 121}
# {'_id': ObjectId('6290c48da64bd56182400872'),
#  'climate': [{'air_temperature_celcius': 21}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 18, 3, 50, 40),
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400874'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 17, 4, 48, 20),
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('6290c48da64bd56182400876'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 17, 4, 45, 10),
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('6290c48da64bd56182400878'),
#  'climate': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 3, 17, 4, 45),
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd56182400880'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 24, 40),
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('6290c48da64bd56182400881'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 22, 20),
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd56182400882'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 20, 50),
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400884'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 16, 30),
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd56182400885'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 16, 20),
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('6290c48da64bd56182400887'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 14, 40),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400888'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 14, 30),
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('6290c48da64bd56182400889'),
#  'climate': [{'air_temperature_celcius': 25}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 14, 30),
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('6290c48da64bd5618240088c'),
#  'climate': [{'air_temperature_celcius': 21}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 33, 50),
#  'surface_temperature_celcius': 105}
# {'_id': ObjectId('6290c48da64bd5618240088d'),
#  'climate': [{'air_temperature_celcius': 21}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 29, 50),
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('6290c48da64bd5618240088e'),
#  'climate': [{'air_temperature_celcius': 21}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 28, 20),
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('6290c48da64bd5618240088f'),
#  'climate': [{'air_temperature_celcius': 21}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 28),
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('6290c48da64bd56182400890'),
#  'climate': [{'air_temperature_celcius': 21}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 27, 20),
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('6290c48da64bd56182400891'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 48, 40),
#  'surface_temperature_celcius': 105}
# {'_id': ObjectId('6290c48da64bd56182400892'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 46, 20),
#  'surface_temperature_celcius': 109}
# {'_id': ObjectId('6290c48da64bd56182400893'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 45, 30),
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('6290c48da64bd56182400894'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 45, 30),
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('6290c48da64bd56182400895'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 43, 50),
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400899'),
#  'climate': [{'air_temperature_celcius': 23}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 3, 9, 13, 23, 40),
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd5618240089e'),
#  'climate': [{'air_temperature_celcius': 19}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 3, 7, 4, 16, 10),
#  'surface_temperature_celcius': 64}
# {'_id': ObjectId('6290c48da64bd5618240089f'),
#  'climate': [{'air_temperature_celcius': 20}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 6, 5, 6, 30),
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('6290c48da64bd561824008a0'),
#  'climate': [{'air_temperature_celcius': 20}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 6, 5, 6, 20),
#  'surface_temperature_celcius': 59}

# %% [markdown]
# ##### e. Find the top 10 records with the highest surface temperature (°C)

# %%
# sort in descending order, and only show 10 records
results = hotspot_collection.aggregate([{"$sort": {"surface_temperature_celcius":-1}},{"$limit": 10}])
for x in results:
    pprint(x)
# Out:
# {'_id': ObjectId('6290c48da64bd561824002d8'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 18, 4, 52),
#  'latitude': -38.1665,
#  'longitude': 143.062,
#  'surface_temperature_celcius': 124}
# {'_id': ObjectId('6290c48da64bd56182400782'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#  'latitude': -36.343,
#  'longitude': 142.1986,
#  'surface_temperature_celcius': 123}
# {'_id': ObjectId('6290c48da64bd5618240024a'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 5, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 1, 4, 14, 20),
#  'latitude': -36.9318,
#  'longitude': 143.0907,
#  'surface_temperature_celcius': 122}
# {'_id': ObjectId('6290c48da64bd56182400871'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 3, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 18, 3, 50, 50),
#  'latitude': -37.016999999999996,
#  'longitude': 148.1297,
#  'surface_temperature_celcius': 121}
# {'_id': ObjectId('6290c48da64bd5618240005c'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 20),
#  'latitude': -34.9938,
#  'longitude': 141.876,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('6290c48da64bd56182400749'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 40),
#  'latitude': -36.1057,
#  'longitude': 141.7608,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('6290c48da64bd56182400789'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#  'latitude': -36.3521,
#  'longitude': 142.2008,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('6290c48da64bd561824004f4'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 13, 4, 28, 10),
#  'latitude': -37.0745,
#  'longitude': 141.0692,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('6290c48da64bd56182400371'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 18, 4, 44, 50),
#  'latitude': -37.8326,
#  'longitude': 143.4999,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('6290c48da64bd561824001a0'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 5, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 4, 4, 44, 50),
#  'latitude': -36.4057,
#  'longitude': 140.9806,
#  'surface_temperature_celcius': 119}

# %% [markdown]
# ##### f. Find the number of fires each day. You are required to only display the total number of fires and the date in the output.

# %%
# join based on date, and only project necessary fields based on the length of the hotspots list
result = db.climate.aggregate([
    {
    "$lookup":{
        "from": "hotspot",
        "localField": "date",
        "foreignField": "date",
        "as":"Number of fires",
        }
    },
    {"$project": {"date":1,"Number of fires":{"$size":"$Number of fires"},"_id":0}}
])
for x in result:
    pprint(x)
# Out:
# {'Number of fires': 0, 'date': datetime.datetime(2020, 12, 31, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 3, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 4, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 5, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 6, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 7, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 8, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 9, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 11, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 12, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 13, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 14, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 15, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 17, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 21, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 22, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 23, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 25, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 28, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 30, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 31, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 1, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 3, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 4, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 5, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 6, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 7, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 8, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 9, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 11, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 12, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 13, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 14, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 15, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 17, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 21, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 22, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 23, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 25, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 2, 28, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 1, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 3, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 4, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 5, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 3, 6, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 3, 7, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 3, 8, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 3, 9, 0, 0)}
# {'Number of fires': 8, 'date': datetime.datetime(2021, 3, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 11, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 3, 12, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 3, 13, 0, 0)}
# {'Number of fires': 10, 'date': datetime.datetime(2021, 3, 14, 0, 0)}
# {'Number of fires': 7, 'date': datetime.datetime(2021, 3, 15, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 16, 0, 0)}
# {'Number of fires': 6, 'date': datetime.datetime(2021, 3, 17, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 3, 18, 0, 0)}
# {'Number of fires': 21, 'date': datetime.datetime(2021, 3, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 21, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 22, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 23, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 3, 24, 0, 0)}
# {'Number of fires': 13, 'date': datetime.datetime(2021, 3, 25, 0, 0)}
# {'Number of fires': 17, 'date': datetime.datetime(2021, 3, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 27, 0, 0)}
# {'Number of fires': 54, 'date': datetime.datetime(2021, 3, 28, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 3, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 3, 30, 0, 0)}
# {'Number of fires': 22, 'date': datetime.datetime(2021, 3, 31, 0, 0)}
# {'Number of fires': 7, 'date': datetime.datetime(2021, 4, 1, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 4, 2, 0, 0)}
# {'Number of fires': 72, 'date': datetime.datetime(2021, 4, 3, 0, 0)}
# {'Number of fires': 89, 'date': datetime.datetime(2021, 4, 4, 0, 0)}
# {'Number of fires': 49, 'date': datetime.datetime(2021, 4, 5, 0, 0)}
# {'Number of fires': 118, 'date': datetime.datetime(2021, 4, 6, 0, 0)}
# {'Number of fires': 39, 'date': datetime.datetime(2021, 4, 7, 0, 0)}
# {'Number of fires': 20, 'date': datetime.datetime(2021, 4, 8, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 4, 9, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 4, 10, 0, 0)}
# {'Number of fires': 24, 'date': datetime.datetime(2021, 4, 11, 0, 0)}
# {'Number of fires': 69, 'date': datetime.datetime(2021, 4, 12, 0, 0)}
# {'Number of fires': 357, 'date': datetime.datetime(2021, 4, 13, 0, 0)}
# {'Number of fires': 18, 'date': datetime.datetime(2021, 4, 14, 0, 0)}
# {'Number of fires': 69, 'date': datetime.datetime(2021, 4, 15, 0, 0)}
# {'Number of fires': 18, 'date': datetime.datetime(2021, 4, 16, 0, 0)}
# {'Number of fires': 38, 'date': datetime.datetime(2021, 4, 17, 0, 0)}
# {'Number of fires': 325, 'date': datetime.datetime(2021, 4, 18, 0, 0)}
# {'Number of fires': 50, 'date': datetime.datetime(2021, 4, 19, 0, 0)}
# {'Number of fires': 31, 'date': datetime.datetime(2021, 4, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 4, 21, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 4, 22, 0, 0)}
# {'Number of fires': 19, 'date': datetime.datetime(2021, 4, 23, 0, 0)}
# {'Number of fires': 8, 'date': datetime.datetime(2021, 4, 24, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 4, 25, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 4, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 4, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 4, 28, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 4, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 4, 30, 0, 0)}
# {'Number of fires': 20, 'date': datetime.datetime(2021, 5, 1, 0, 0)}
# {'Number of fires': 10, 'date': datetime.datetime(2021, 5, 2, 0, 0)}
# {'Number of fires': 64, 'date': datetime.datetime(2021, 5, 3, 0, 0)}
# {'Number of fires': 135, 'date': datetime.datetime(2021, 5, 4, 0, 0)}
# {'Number of fires': 31, 'date': datetime.datetime(2021, 5, 5, 0, 0)}
# {'Number of fires': 17, 'date': datetime.datetime(2021, 5, 6, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 5, 7, 0, 0)}
# {'Number of fires': 24, 'date': datetime.datetime(2021, 5, 8, 0, 0)}
# {'Number of fires': 13, 'date': datetime.datetime(2021, 5, 9, 0, 0)}
# {'Number of fires': 114, 'date': datetime.datetime(2021, 5, 10, 0, 0)}
# {'Number of fires': 19, 'date': datetime.datetime(2021, 5, 11, 0, 0)}
# {'Number of fires': 10, 'date': datetime.datetime(2021, 5, 12, 0, 0)}
# {'Number of fires': 54, 'date': datetime.datetime(2021, 5, 13, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 5, 14, 0, 0)}
# {'Number of fires': 102, 'date': datetime.datetime(2021, 5, 15, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 5, 16, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 5, 17, 0, 0)}
# {'Number of fires': 7, 'date': datetime.datetime(2021, 5, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 21, 0, 0)}
# {'Number of fires': 33, 'date': datetime.datetime(2021, 5, 22, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 5, 23, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 5, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 25, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 5, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 28, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 30, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 5, 31, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 6, 1, 0, 0)}
# {'Number of fires': 11, 'date': datetime.datetime(2021, 6, 2, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 6, 3, 0, 0)}
# {'Number of fires': 9, 'date': datetime.datetime(2021, 6, 4, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 5, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 6, 0, 0)}
# {'Number of fires': 14, 'date': datetime.datetime(2021, 6, 7, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 8, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 6, 9, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 10, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 6, 11, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 12, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 6, 13, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 6, 14, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 15, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 6, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 17, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 6, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 19, 0, 0)}
# {'Number of fires': 6, 'date': datetime.datetime(2021, 6, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 21, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 6, 22, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 23, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 25, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 28, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 6, 29, 0, 0)}
# {'Number of fires': 6, 'date': datetime.datetime(2021, 6, 30, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 7, 1, 0, 0)}
# {'Number of fires': 8, 'date': datetime.datetime(2021, 7, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 3, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 7, 4, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 7, 5, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 7, 6, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 7, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 8, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 9, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 11, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 12, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 13, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 7, 14, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 15, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 17, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 21, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 22, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 23, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 25, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 28, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 7, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 7, 30, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 7, 31, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 8, 1, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 8, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 3, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 4, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 8, 5, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 6, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 7, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 8, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 9, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 8, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 11, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 12, 0, 0)}
# {'Number of fires': 9, 'date': datetime.datetime(2021, 8, 13, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 8, 14, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 15, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 17, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 20, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 21, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 22, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 23, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 25, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 28, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 30, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 8, 31, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 1, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 3, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 4, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 5, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 6, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 7, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 8, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 9, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 9, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 11, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 12, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 13, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 14, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 15, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 17, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 19, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 9, 20, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 9, 21, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 9, 22, 0, 0)}
# {'Number of fires': 23, 'date': datetime.datetime(2021, 9, 23, 0, 0)}
# {'Number of fires': 28, 'date': datetime.datetime(2021, 9, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 25, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 9, 26, 0, 0)}
# {'Number of fires': 7, 'date': datetime.datetime(2021, 9, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 28, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 9, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 9, 30, 0, 0)}
# {'Number of fires': 8, 'date': datetime.datetime(2021, 10, 1, 0, 0)}
# {'Number of fires': 7, 'date': datetime.datetime(2021, 10, 2, 0, 0)}
# {'Number of fires': 18, 'date': datetime.datetime(2021, 10, 3, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 10, 4, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 5, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 10, 6, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 10, 7, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 10, 8, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 10, 9, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 10, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 11, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 12, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 13, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 14, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 10, 15, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 10, 16, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 10, 17, 0, 0)}
# {'Number of fires': 6, 'date': datetime.datetime(2021, 10, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 19, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 10, 20, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 10, 21, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 22, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 10, 23, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 25, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 10, 26, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 10, 27, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 10, 28, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 30, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 10, 31, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 1, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 3, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 4, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 11, 5, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 6, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 7, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 11, 8, 0, 0)}
# {'Number of fires': 10, 'date': datetime.datetime(2021, 11, 9, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 10, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 11, 11, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 11, 12, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 11, 13, 0, 0)}
# {'Number of fires': 3, 'date': datetime.datetime(2021, 11, 14, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 15, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 17, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 20, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 11, 21, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 11, 22, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 11, 23, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 24, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 25, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 26, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 11, 27, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 11, 28, 0, 0)}
# {'Number of fires': 8, 'date': datetime.datetime(2021, 11, 29, 0, 0)}
# {'Number of fires': 31, 'date': datetime.datetime(2021, 11, 30, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 1, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 2, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 3, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 4, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 5, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 6, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 7, 0, 0)}
# {'Number of fires': 5, 'date': datetime.datetime(2021, 12, 8, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 12, 9, 0, 0)}
# {'Number of fires': 2, 'date': datetime.datetime(2021, 12, 10, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 11, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 12, 12, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 12, 13, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 12, 14, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 12, 15, 0, 0)}
# {'Number of fires': 15, 'date': datetime.datetime(2021, 12, 16, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 17, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 18, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 19, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 20, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 12, 21, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 22, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 23, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 12, 24, 0, 0)}
# {'Number of fires': 1, 'date': datetime.datetime(2021, 12, 25, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 26, 0, 0)}
# {'Number of fires': 4, 'date': datetime.datetime(2021, 12, 27, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 28, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 29, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 30, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 12, 31, 0, 0)}
# {'Number of fires': 0, 'date': datetime.datetime(2021, 1, 1, 0, 0)}

# %% [markdown]
# ##### g. Find the records of fires where the confidence is below 70.

# %%
result = db.hotspot.aggregate([{
    "$lookup":
    {
        "from": "climate",
        "localField": "date",
        "foreignField": "date",
        "as":"climate",
    }},
    {
    "$match" : {"confidence":{"$lt": 70}}
    }])
for x in result:
    pprint(x)
# Out:
# {'_id': ObjectId('6290c48da64bd561823ffe37'),
#  'climate': [{'GHI_w/m2': 223,
#               '_id': ObjectId('6290c48ca64bd561823ffe2f'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 12, 27, 0, 0),
#               'max_wind_speed': 15.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 58.3,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 67,
#  'date': datetime.datetime(2021, 12, 27, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#  'latitude': -35.554,
#  'longitude': 143.30700000000002,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd561823ffe3a'),
#  'climate': [{'GHI_w/m2': 141,
#               '_id': ObjectId('6290c48ca64bd561823ffe2c'),
#               'air_temperature_celcius': 16,
#               'date': datetime.datetime(2021, 12, 24, 0, 0),
#               'max_wind_speed': 16.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 47.0,
#               'station': 948702,
#               'windspeed_knots': 12.0}],
#  'confidence': 65,
#  'date': datetime.datetime(2021, 12, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 24, 13, 12, 1),
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('6290c48da64bd561823ffe3d'),
#  'climate': [{'GHI_w/m2': 150,
#               '_id': ObjectId('6290c48ca64bd561823ffe24'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 12, 16, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.7,
#               'station': 948702,
#               'windspeed_knots': 9.0}],
#  'confidence': 69,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 15, 38, 39),
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('6290c48da64bd561823ffe3e'),
#  'climate': [{'GHI_w/m2': 150,
#               '_id': ObjectId('6290c48ca64bd561823ffe24'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 12, 16, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.7,
#               'station': 948702,
#               'windspeed_knots': 9.0}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 4, 35, 15),
#  'latitude': -37.82,
#  'longitude': 142.32299999999998,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe42'),
#  'climate': [{'GHI_w/m2': 150,
#               '_id': ObjectId('6290c48ca64bd561823ffe24'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 12, 16, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.7,
#               'station': 948702,
#               'windspeed_knots': 9.0}],
#  'confidence': 59,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 57),
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd561823ffe47'),
#  'climate': [{'GHI_w/m2': 150,
#               '_id': ObjectId('6290c48ca64bd561823ffe24'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 12, 16, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.7,
#               'station': 948702,
#               'windspeed_knots': 9.0}],
#  'confidence': 60,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 0, 21, 11),
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823ffe4a'),
#  'climate': [{'GHI_w/m2': 150,
#               '_id': ObjectId('6290c48ca64bd561823ffe24'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 12, 16, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.7,
#               'station': 948702,
#               'windspeed_knots': 9.0}],
#  'confidence': 53,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 0, 20, 53),
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd561823ffe4d'),
#  'climate': [{'GHI_w/m2': 152,
#               '_id': ObjectId('6290c48ca64bd561823ffe23'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 12, 15, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 52.0,
#               'station': 948702,
#               'windspeed_knots': 7.1}],
#  'confidence': 51,
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 15, 13, 17, 17),
#  'latitude': -37.623000000000005,
#  'longitude': 149.32299999999998,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('6290c48da64bd561823ffe4e'),
#  'climate': [{'GHI_w/m2': 152,
#               '_id': ObjectId('6290c48ca64bd561823ffe23'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 12, 15, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 52.0,
#               'station': 948702,
#               'windspeed_knots': 7.1}],
#  'confidence': 65,
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 15, 1, 16, 23),
#  'latitude': -38.038000000000004,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('6290c48da64bd561823ffe51'),
#  'climate': [{'GHI_w/m2': 156,
#               '_id': ObjectId('6290c48ca64bd561823ffe20'),
#               'air_temperature_celcius': 19,
#               'date': datetime.datetime(2021, 12, 12, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.3,
#               'station': 948702,
#               'windspeed_knots': 6.2}],
#  'confidence': 53,
#  'date': datetime.datetime(2021, 12, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 12, 0, 45, 38),
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('6290c48da64bd561823ffe52'),
#  'climate': [{'GHI_w/m2': 141,
#               '_id': ObjectId('6290c48ca64bd561823ffe1e'),
#               'air_temperature_celcius': 17,
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.5,
#               'station': 948702,
#               'windspeed_knots': 7.3}],
#  'confidence': 50,
#  'date': datetime.datetime(2021, 12, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 10, 0, 57, 59),
#  'latitude': -37.986999999999995,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('6290c48da64bd561823ffe53'),
#  'climate': [{'GHI_w/m2': 141,
#               '_id': ObjectId('6290c48ca64bd561823ffe1e'),
#               'air_temperature_celcius': 17,
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.5,
#               'station': 948702,
#               'windspeed_knots': 7.3}],
#  'confidence': 67,
#  'date': datetime.datetime(2021, 12, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 10, 0, 56, 57),
#  'latitude': -34.289,
#  'longitude': 141.71200000000002,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe5c'),
#  'climate': [{'GHI_w/m2': 131,
#               '_id': ObjectId('6290c48ca64bd561823ffe1c'),
#               'air_temperature_celcius': 15,
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'G',
#               'relative_humidity': 48.1,
#               'station': 948702,
#               'windspeed_knots': 7.9}],
#  'confidence': 56,
#  'date': datetime.datetime(2021, 12, 8, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 43),
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('6290c48da64bd561823ffe5d'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 52,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 23, 25, 57),
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('6290c48da64bd561823ffe5f'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 51,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffe60'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffe62'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 69,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#  'latitude': -37.58,
#  'longitude': 149.33100000000002,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('6290c48da64bd561823ffe64'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 61,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 32),
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('6290c48da64bd561823ffe65'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('6290c48da64bd561823ffe66'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('6290c48da64bd561823ffe72'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 69,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823ffe73'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 60,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 0, 21),
#  'latitude': -37.637,
#  'longitude': 146.28799999999998,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffe7a'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 69,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd561823ffe7b'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe14'),
#               'air_temperature_celcius': 26,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.2,
#               'precipitation_type': 'G',
#               'relative_humidity': 61.0,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 49),
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd561823ffe7c'),
#  'climate': [{'GHI_w/m2': 227,
#               '_id': ObjectId('6290c48ca64bd561823ffe13'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 11, 29, 0, 0),
#               'max_wind_speed': 16.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 56.7,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 53,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#  'latitude': -37.611,
#  'longitude': 149.27700000000002,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('6290c48da64bd561823ffe7e'),
#  'climate': [{'GHI_w/m2': 227,
#               '_id': ObjectId('6290c48ca64bd561823ffe13'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 11, 29, 0, 0),
#               'max_wind_speed': 16.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 56.7,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd561823ffe7f'),
#  'climate': [{'GHI_w/m2': 227,
#               '_id': ObjectId('6290c48ca64bd561823ffe13'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 11, 29, 0, 0),
#               'max_wind_speed': 16.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 56.7,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 52,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 3, 53, 16),
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe81'),
#  'climate': [{'GHI_w/m2': 227,
#               '_id': ObjectId('6290c48ca64bd561823ffe13'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 11, 29, 0, 0),
#               'max_wind_speed': 16.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 56.7,
#               'station': 948702,
#               'windspeed_knots': 9.3}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('6290c48da64bd561823ffe84'),
#  'climate': [{'GHI_w/m2': 183,
#               '_id': ObjectId('6290c48ca64bd561823ffe12'),
#               'air_temperature_celcius': 23,
#               'date': datetime.datetime(2021, 11, 28, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 58.8,
#               'station': 948702,
#               'windspeed_knots': 8.8}],
#  'confidence': 50,
#  'date': datetime.datetime(2021, 11, 28, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 28, 0, 33, 14),
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffe87'),
#  'climate': [{'GHI_w/m2': 194,
#               '_id': ObjectId('6290c48ca64bd561823ffe0d'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 11, 23, 0, 0),
#               'max_wind_speed': 9.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 56.8,
#               'station': 948702,
#               'windspeed_knots': 5.7}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 11, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 23, 0, 15, 12),
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('6290c48da64bd561823ffe88'),
#  'climate': [{'GHI_w/m2': 194,
#               '_id': ObjectId('6290c48ca64bd561823ffe0d'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 11, 23, 0, 0),
#               'max_wind_speed': 9.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 56.8,
#               'station': 948702,
#               'windspeed_knots': 5.7}],
#  'confidence': 63,
#  'date': datetime.datetime(2021, 11, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 23, 0, 14, 47),
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('6290c48da64bd561823ffe8e'),
#  'climate': [{'GHI_w/m2': 243,
#               '_id': ObjectId('6290c48ca64bd561823ffe04'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'max_wind_speed': 22.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 48.3,
#               'station': 948702,
#               'windspeed_knots': 11.9}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 14, 0, 21, 26),
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('6290c48da64bd561823ffe8f'),
#  'climate': [{'GHI_w/m2': 243,
#               '_id': ObjectId('6290c48ca64bd561823ffe04'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'max_wind_speed': 22.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 48.3,
#               'station': 948702,
#               'windspeed_knots': 11.9}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 14, 0, 21, 7),
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('6290c48da64bd561823ffe92'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe03'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 11, 13, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 51.9,
#               'station': 948702,
#               'windspeed_knots': 7.3}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 13, 3, 52, 8),
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffe93'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe03'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 11, 13, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 51.9,
#               'station': 948702,
#               'windspeed_knots': 7.3}],
#  'confidence': 51,
#  'date': datetime.datetime(2021, 11, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 13, 1, 16, 38),
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('6290c48da64bd561823ffe94'),
#  'climate': [{'GHI_w/m2': 202,
#               '_id': ObjectId('6290c48ca64bd561823ffe03'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 11, 13, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 51.9,
#               'station': 948702,
#               'windspeed_knots': 7.3}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 11, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 13, 1, 16, 37),
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd561823ffe95'),
#  'climate': [{'GHI_w/m2': 149,
#               '_id': ObjectId('6290c48ca64bd561823ffe02'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 11, 12, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.8,
#               'station': 948702,
#               'windspeed_knots': 6.7}],
#  'confidence': 63,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 4, 47, 32),
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('6290c48da64bd561823ffe96'),
#  'climate': [{'GHI_w/m2': 149,
#               '_id': ObjectId('6290c48ca64bd561823ffe02'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 11, 12, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.8,
#               'station': 948702,
#               'windspeed_knots': 6.7}],
#  'confidence': 58,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 4, 47, 16),
#  'latitude': -37.864000000000004,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd561823ffe97'),
#  'climate': [{'GHI_w/m2': 149,
#               '_id': ObjectId('6290c48ca64bd561823ffe02'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 11, 12, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.8,
#               'station': 948702,
#               'windspeed_knots': 6.7}],
#  'confidence': 56,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 4, 46, 53),
#  'latitude': -38.912,
#  'longitude': 146.27200000000002,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd561823ffe98'),
#  'climate': [{'GHI_w/m2': 149,
#               '_id': ObjectId('6290c48ca64bd561823ffe02'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 11, 12, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.8,
#               'station': 948702,
#               'windspeed_knots': 6.7}],
#  'confidence': 67,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 0, 33, 15),
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffe9a'),
#  'climate': [{'GHI_w/m2': 147,
#               '_id': ObjectId('6290c48ca64bd561823ffe01'),
#               'air_temperature_celcius': 18,
#               'date': datetime.datetime(2021, 11, 11, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.6,
#               'station': 948702,
#               'windspeed_knots': 8.2}],
#  'confidence': 51,
#  'date': datetime.datetime(2021, 11, 11, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 11, 15, 8),
#  'latitude': -36.943000000000005,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('6290c48da64bd561823ffe9e'),
#  'climate': [{'GHI_w/m2': 119,
#               '_id': ObjectId('6290c48ca64bd561823ffdff'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 11, 9, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 50.9,
#               'station': 948702,
#               'windspeed_knots': 5.9}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 11, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 56),
#  'latitude': -36.759,
#  'longitude': 145.179,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823ffe9f'),
#  'climate': [{'GHI_w/m2': 119,
#               '_id': ObjectId('6290c48ca64bd561823ffdff'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 11, 9, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 50.9,
#               'station': 948702,
#               'windspeed_knots': 5.9}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 11, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 56),
#  'latitude': -36.758,
#  'longitude': 145.19,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('6290c48da64bd561823ffea5'),
#  'climate': [{'GHI_w/m2': 119,
#               '_id': ObjectId('6290c48ca64bd561823ffdff'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 11, 9, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 50.9,
#               'station': 948702,
#               'windspeed_knots': 5.9}],
#  'confidence': 63,
#  'date': datetime.datetime(2021, 11, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 46),
#  'latitude': -37.719,
#  'longitude': 142.154,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd561823ffea8'),
#  'climate': [{'GHI_w/m2': 106,
#               '_id': ObjectId('6290c48ca64bd561823ffdfe'),
#               'air_temperature_celcius': 12,
#               'date': datetime.datetime(2021, 11, 8, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'G',
#               'relative_humidity': 46.6,
#               'station': 948702,
#               'windspeed_knots': 6.7}],
#  'confidence': 60,
#  'date': datetime.datetime(2021, 11, 8, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 8, 5, 12, 8),
#  'latitude': -36.538000000000004,
#  'longitude': 141.129,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd561823ffeaf'),
#  'climate': [{'GHI_w/m2': 193,
#               '_id': ObjectId('6290c48ca64bd561823ffdf2'),
#               'air_temperature_celcius': 22,
#               'date': datetime.datetime(2021, 10, 27, 0, 0),
#               'max_wind_speed': 19.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 46.9,
#               'station': 948702,
#               'windspeed_knots': 12.9}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 10, 27, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 27, 4, 47, 31),
#  'latitude': -36.748000000000005,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('6290c48da64bd561823ffeb7'),
#  'climate': [{'GHI_w/m2': 111,
#               '_id': ObjectId('6290c48ca64bd561823ffdf1'),
#               'air_temperature_celcius': 13,
#               'date': datetime.datetime(2021, 10, 26, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 50.4,
#               'station': 948702,
#               'windspeed_knots': 7.9}],
#  'confidence': 67,
#  'date': datetime.datetime(2021, 10, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 26, 4, 4, 53),
#  'latitude': -36.156,
#  'longitude': 143.56799999999998,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd561823ffeb8'),
#  'climate': [{'GHI_w/m2': 111,
#               '_id': ObjectId('6290c48ca64bd561823ffdf1'),
#               'air_temperature_celcius': 13,
#               'date': datetime.datetime(2021, 10, 26, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 50.4,
#               'station': 948702,
#               'windspeed_knots': 7.9}],
#  'confidence': 69,
#  'date': datetime.datetime(2021, 10, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 26, 4, 4, 53),
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('6290c48da64bd561823ffebc'),
#  'climate': [{'GHI_w/m2': 105,
#               '_id': ObjectId('6290c48ca64bd561823ffdec'),
#               'air_temperature_celcius': 12,
#               'date': datetime.datetime(2021, 10, 21, 0, 0),
#               'max_wind_speed': 14.0,
#               'precipitation ': 0.02,
#               'precipitation_type': 'G',
#               'relative_humidity': 47.3,
#               'station': 948702,
#               'windspeed_knots': 9.7}],
#  'confidence': 65,
#  'date': datetime.datetime(2021, 10, 21, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 21, 1, 9, 54),
#  'latitude': -36.1,
#  'longitude': 143.77200000000002,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('6290c48da64bd561823ffec0'),
#  'climate': [{'GHI_w/m2': 119,
#               '_id': ObjectId('6290c48ca64bd561823ffdeb'),
#               'air_temperature_celcius': 13,
#               'date': datetime.datetime(2021, 10, 20, 0, 0),
#               'max_wind_speed': 16.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'G',
#               'relative_humidity': 42.0,
#               'station': 948702,
#               'windspeed_knots': 11.4}],
#  'confidence': 65,
#  'date': datetime.datetime(2021, 10, 20, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 20, 0, 27, 12),
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd561823ffeca'),
#  'climate': [{'GHI_w/m2': 194,
#               '_id': ObjectId('6290c48ca64bd561823ffde8'),
#               'air_temperature_celcius': 22,
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'max_wind_speed': 16.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 46.8,
#               'station': 948702,
#               'windspeed_knots': 8.0}],
#  'confidence': 58,
#  'date': datetime.datetime(2021, 10, 17, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 17, 4, 10, 38),
#  'latitude': -37.586999999999996,
#  'longitude': 142.47899999999998,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd561823ffecc'),
#  'climate': [{'GHI_w/m2': 157,
#               '_id': ObjectId('6290c48ca64bd561823ffde7'),
#               'air_temperature_celcius': 19,
#               'date': datetime.datetime(2021, 10, 16, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 54.3,
#               'station': 948702,
#               'windspeed_knots': 5.9}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 10, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 16, 23, 56, 43),
#  'latitude': -37.288000000000004,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('6290c48da64bd561823ffed8'),
#  'climate': [{'GHI_w/m2': 162,
#               '_id': ObjectId('6290c48ca64bd561823ffddb'),
#               'air_temperature_celcius': 19,
#               'date': datetime.datetime(2021, 10, 4, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 50.3,
#               'station': 948702,
#               'windspeed_knots': 7.7}],
#  'confidence': 50,
#  'date': datetime.datetime(2021, 10, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41, 36),
#  'latitude': -36.418,
#  'longitude': 141.596,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('6290c48da64bd561823ffedd'),
#  'climate': [{'GHI_w/m2': 115,
#               '_id': ObjectId('6290c48ca64bd561823ffdda'),
#               'air_temperature_celcius': 13,
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 46.2,
#               'station': 948702,
#               'windspeed_knots': 5.6}],
#  'confidence': 69,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 15, 1, 44),
#  'latitude': -37.461,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('6290c48da64bd561823ffedf'),
#  'climate': [{'GHI_w/m2': 115,
#               '_id': ObjectId('6290c48ca64bd561823ffdda'),
#               'air_temperature_celcius': 13,
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 46.2,
#               'station': 948702,
#               'windspeed_knots': 5.6}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 28),
#  'latitude': -37.236,
#  'longitude': 141.17600000000002,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('6290c48da64bd561823ffee0'),
#  'climate': [{'GHI_w/m2': 115,
#               '_id': ObjectId('6290c48ca64bd561823ffdda'),
#               'air_temperature_celcius': 13,
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 46.2,
#               'station': 948702,
#               'windspeed_knots': 5.6}],
#  'confidence': 59,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 28),
#  'latitude': -37.227,
#  'longitude': 141.151,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('6290c48da64bd561823ffeee'),
#  'climate': [{'GHI_w/m2': 115,
#               '_id': ObjectId('6290c48ca64bd561823ffdda'),
#               'air_temperature_celcius': 13,
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 46.2,
#               'station': 948702,
#               'windspeed_knots': 5.6}],
#  'confidence': 54,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 1, 22, 44),
#  'latitude': -37.227,
#  'longitude': 141.14600000000002,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('6290c48da64bd561823ffeef'),
#  'climate': [{'GHI_w/m2': 99,
#               '_id': ObjectId('6290c48ca64bd561823ffdd9'),
#               'air_temperature_celcius': 11,
#               'date': datetime.datetime(2021, 10, 2, 0, 0),
#               'max_wind_speed': 9.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 44.2,
#               'station': 948702,
#               'windspeed_knots': 5.8}],
#  'confidence': 50,
#  'date': datetime.datetime(2021, 10, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 2, 23, 44, 31),
#  'latitude': -37.466,
#  'longitude': 148.1,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('6290c48da64bd561823ffef0'),
#  'climate': [{'GHI_w/m2': 99,
#               '_id': ObjectId('6290c48ca64bd561823ffdd9'),
#               'air_temperature_celcius': 11,
#               'date': datetime.datetime(2021, 10, 2, 0, 0),
#               'max_wind_speed': 9.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 44.2,
#               'station': 948702,
#               'windspeed_knots': 5.8}],
#  'confidence': 59,
#  'date': datetime.datetime(2021, 10, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 2, 4, 53, 10),
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('6290c48da64bd561823ffef5'),
#  'climate': [{'GHI_w/m2': 99,
#               '_id': ObjectId('6290c48ca64bd561823ffdd9'),
#               'air_temperature_celcius': 11,
#               'date': datetime.datetime(2021, 10, 2, 0, 0),
#               'max_wind_speed': 9.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 44.2,
#               'station': 948702,
#               'windspeed_knots': 5.8}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 10, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 2, 0, 39, 34),
#  'latitude': -37.455999999999996,
#  'longitude': 148.11,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('6290c48da64bd561823ffef6'),
#  'climate': [{'GHI_w/m2': 105,
#               '_id': ObjectId('6290c48ca64bd561823ffdd8'),
#               'air_temperature_celcius': 12,
#               'date': datetime.datetime(2021, 10, 1, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'G',
#               'relative_humidity': 47.9,
#               'station': 948702,
#               'windspeed_knots': 6.7}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 10, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 1, 15, 13, 56),
#  'latitude': -37.463,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 34}
# {'_id': ObjectId('6290c48da64bd561823ffefc'),
#  'climate': [{'GHI_w/m2': 105,
#               '_id': ObjectId('6290c48ca64bd561823ffdd8'),
#               'air_temperature_celcius': 12,
#               'date': datetime.datetime(2021, 10, 1, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'G',
#               'relative_humidity': 47.9,
#               'station': 948702,
#               'windspeed_knots': 6.7}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 10, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 1, 4, 10, 28),
#  'latitude': -37.46,
#  'longitude': 148.113,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('6290c48da64bd561823fff04'),
#  'climate': [{'GHI_w/m2': 134,
#               '_id': ObjectId('6290c48ca64bd561823ffdd4'),
#               'air_temperature_celcius': 15,
#               'date': datetime.datetime(2021, 9, 27, 0, 0),
#               'max_wind_speed': 19.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 44.8,
#               'station': 948702,
#               'windspeed_knots': 8.3}],
#  'confidence': 65,
#  'date': datetime.datetime(2021, 9, 27, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 27, 4, 35, 18),
#  'latitude': -36.398,
#  'longitude': 145.286,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('6290c48da64bd561823fff07'),
#  'climate': [{'GHI_w/m2': 102,
#               '_id': ObjectId('6290c48ca64bd561823ffdd3'),
#               'air_temperature_celcius': 11,
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'max_wind_speed': 8.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'G',
#               'relative_humidity': 40.8,
#               'station': 948702,
#               'windspeed_knots': 6.4}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 9, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 26, 3, 52, 14),
#  'latitude': -37.086999999999996,
#  'longitude': 145.37,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('6290c48da64bd561823fff14'),
#  'climate': [{'GHI_w/m2': 126,
#               '_id': ObjectId('6290c48ca64bd561823ffdd1'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 9, 24, 0, 0),
#               'max_wind_speed': 23.9,
#               'precipitation ': 0.16,
#               'precipitation_type': 'G',
#               'relative_humidity': 44.0,
#               'station': 948702,
#               'windspeed_knots': 14.4}],
#  'confidence': 59,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'latitude': -37.375,
#  'longitude': 148.063,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('6290c48da64bd561823fff1a'),
#  'climate': [{'GHI_w/m2': 126,
#               '_id': ObjectId('6290c48ca64bd561823ffdd1'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 9, 24, 0, 0),
#               'max_wind_speed': 23.9,
#               'precipitation ': 0.16,
#               'precipitation_type': 'G',
#               'relative_humidity': 44.0,
#               'station': 948702,
#               'windspeed_knots': 14.4}],
#  'confidence': 58,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 19),
#  'latitude': -37.397,
#  'longitude': 148.121,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd561823fff1b'),
#  'climate': [{'GHI_w/m2': 126,
#               '_id': ObjectId('6290c48ca64bd561823ffdd1'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 9, 24, 0, 0),
#               'max_wind_speed': 23.9,
#               'precipitation ': 0.16,
#               'precipitation_type': 'G',
#               'relative_humidity': 44.0,
#               'station': 948702,
#               'windspeed_knots': 14.4}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('6290c48da64bd561823fff1c'),
#  'climate': [{'GHI_w/m2': 126,
#               '_id': ObjectId('6290c48ca64bd561823ffdd1'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 9, 24, 0, 0),
#               'max_wind_speed': 23.9,
#               'precipitation ': 0.16,
#               'precipitation_type': 'G',
#               'relative_humidity': 44.0,
#               'station': 948702,
#               'windspeed_knots': 14.4}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'latitude': -37.465,
#  'longitude': 148.153,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('6290c48da64bd561823fff1d'),
#  'climate': [{'GHI_w/m2': 126,
#               '_id': ObjectId('6290c48ca64bd561823ffdd1'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 9, 24, 0, 0),
#               'max_wind_speed': 23.9,
#               'precipitation ': 0.16,
#               'precipitation_type': 'G',
#               'relative_humidity': 44.0,
#               'station': 948702,
#               'windspeed_knots': 14.4}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('6290c48da64bd561823fff20'),
#  'climate': [{'GHI_w/m2': 126,
#               '_id': ObjectId('6290c48ca64bd561823ffdd1'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 9, 24, 0, 0),
#               'max_wind_speed': 23.9,
#               'precipitation ': 0.16,
#               'precipitation_type': 'G',
#               'relative_humidity': 44.0,
#               'station': 948702,
#               'windspeed_knots': 14.4}],
#  'confidence': 61,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 17),
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('6290c48da64bd561823fff23'),
#  'climate': [{'GHI_w/m2': 126,
#               '_id': ObjectId('6290c48ca64bd561823ffdd1'),
#               'air_temperature_celcius': 14,
#               'date': datetime.datetime(2021, 9, 24, 0, 0),
#               'max_wind_speed': 23.9,
#               'precipitation ': 0.16,
#               'precipitation_type': 'G',
#               'relative_humidity': 44.0,
# ...
#               'max_wind_speed': 15.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 61.9,
#               'station': 948701,
#               'windspeed_knots': 8.0}],
#  'confidence': 62,
#  'date': datetime.datetime(2021, 3, 25, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 25, 4, 3, 10),
#  'latitude': -37.8992,
#  'longitude': 143.4534,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd56182400858'),
#  'climate': [{'GHI_w/m2': 178,
#               '_id': ObjectId('6290c48ca64bd561823ffd1a'),
#               'air_temperature_celcius': 23,
#               'date': datetime.datetime(2021, 3, 25, 0, 0),
#               'max_wind_speed': 15.9,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 61.9,
#               'station': 948701,
#               'windspeed_knots': 8.0}],
#  'confidence': 57,
#  'date': datetime.datetime(2021, 3, 25, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 25, 3, 56, 40),
#  'latitude': -37.9022,
#  'longitude': 143.4607,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('6290c48da64bd56182400859'),
#  'climate': [{'GHI_w/m2': 159,
#               '_id': ObjectId('6290c48ca64bd561823ffd19'),
#               'air_temperature_celcius': 20,
#               'date': datetime.datetime(2021, 3, 24, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 58.4,
#               'station': 948701,
#               'windspeed_knots': 6.1}],
#  'confidence': 65,
#  'date': datetime.datetime(2021, 3, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 24, 4, 58),
#  'latitude': -37.1603,
#  'longitude': 142.8088,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd5618240085a'),
#  'climate': [{'GHI_w/m2': 159,
#               '_id': ObjectId('6290c48ca64bd561823ffd19'),
#               'air_temperature_celcius': 20,
#               'date': datetime.datetime(2021, 3, 24, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 58.4,
#               'station': 948701,
#               'windspeed_knots': 6.1}],
#  'confidence': 55,
#  'date': datetime.datetime(2021, 3, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 24, 4, 56, 10),
#  'latitude': -37.1684,
#  'longitude': 142.8183,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('6290c48da64bd5618240085c'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 58,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#  'latitude': -37.9164,
#  'longitude': 143.4866,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd5618240085e'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 63,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#  'latitude': -37.9257,
#  'longitude': 143.4891,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('6290c48da64bd5618240085f'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 36),
#  'latitude': -37.3982,
#  'longitude': 147.0001,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('6290c48da64bd56182400861'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 59,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 35),
#  'latitude': -37.4023,
#  'longitude': 147.0394,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('6290c48da64bd56182400862'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 60,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 50),
#  'latitude': -37.4336,
#  'longitude': 147.0534,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('6290c48da64bd56182400863'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 61,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 30),
#  'latitude': -37.4003,
#  'longitude': 147.0448,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400864'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 53,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 30),
#  'latitude': -37.9184,
#  'longitude': 143.4745,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd56182400865'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 61,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 10),
#  'latitude': -37.3911,
#  'longitude': 147.037,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('6290c48da64bd56182400869'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 66,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#  'latitude': -37.9277,
#  'longitude': 143.477,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('6290c48da64bd5618240086f'),
#  'climate': [{'GHI_w/m2': 197,
#               '_id': ObjectId('6290c48ca64bd561823ffd14'),
#               'air_temperature_celcius': 24,
#               'date': datetime.datetime(2021, 3, 19, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 55.2,
#               'station': 948701,
#               'windspeed_knots': 5.8}],
#  'confidence': 60,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 0, 12, 50),
#  'latitude': -37.3942,
#  'longitude': 147.0455,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('6290c48da64bd56182400870'),
#  'climate': [{'GHI_w/m2': 176,
#               '_id': ObjectId('6290c48ca64bd561823ffd13'),
#               'air_temperature_celcius': 21,
#               'date': datetime.datetime(2021, 3, 18, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 52.8,
#               'station': 948701,
#               'windspeed_knots': 4.1}],
#  'confidence': 64,
#  'date': datetime.datetime(2021, 3, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 18, 13, 16, 50),
#  'latitude': -37.4313,
#  'longitude': 147.0343,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('6290c48da64bd5618240087b'),
#  'climate': [{'GHI_w/m2': 223,
#               '_id': ObjectId('6290c48ca64bd561823ffd10'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 3, 15, 0, 0),
#               'max_wind_speed': 18.1,
#               'precipitation ': 0.04,
#               'precipitation_type': 'G',
#               'relative_humidity': 58.4,
#               'station': 948701,
#               'windspeed_knots': 11.9}],
#  'confidence': 52,
#  'date': datetime.datetime(2021, 3, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 15, 0, 42, 50),
#  'latitude': -37.4075,
#  'longitude': 147.0233,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd5618240087c'),
#  'climate': [{'GHI_w/m2': 223,
#               '_id': ObjectId('6290c48ca64bd561823ffd10'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 3, 15, 0, 0),
#               'max_wind_speed': 18.1,
#               'precipitation ': 0.04,
#               'precipitation_type': 'G',
#               'relative_humidity': 58.4,
#               'station': 948701,
#               'windspeed_knots': 11.9}],
#  'confidence': 66,
#  'date': datetime.datetime(2021, 3, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 15, 0, 42, 50),
#  'latitude': -37.0228,
#  'longitude': 148.1281,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd5618240087d'),
#  'climate': [{'GHI_w/m2': 223,
#               '_id': ObjectId('6290c48ca64bd561823ffd10'),
#               'air_temperature_celcius': 28,
#               'date': datetime.datetime(2021, 3, 15, 0, 0),
#               'max_wind_speed': 18.1,
#               'precipitation ': 0.04,
#               'precipitation_type': 'G',
#               'relative_humidity': 58.4,
#               'station': 948701,
#               'windspeed_knots': 11.9}],
#  'confidence': 51,
#  'date': datetime.datetime(2021, 3, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 15, 0, 42, 40),
#  'latitude': -37.001999999999995,
#  'longitude': 148.2055,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('6290c48da64bd5618240088a'),
#  'climate': [{'GHI_w/m2': 154,
#               '_id': ObjectId('6290c48ca64bd561823ffd0e'),
#               'air_temperature_celcius': 20,
#               'date': datetime.datetime(2021, 3, 13, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 62.2,
#               'station': 948701,
#               'windspeed_knots': 7.1}],
#  'confidence': 56,
#  'date': datetime.datetime(2021, 3, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 13, 23, 58, 50),
#  'latitude': -37.0286,
#  'longitude': 148.155,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd5618240088b'),
#  'climate': [{'GHI_w/m2': 154,
#               '_id': ObjectId('6290c48ca64bd561823ffd0e'),
#               'air_temperature_celcius': 20,
#               'date': datetime.datetime(2021, 3, 13, 0, 0),
#               'max_wind_speed': 15.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 62.2,
#               'station': 948701,
#               'windspeed_knots': 7.1}],
#  'confidence': 52,
#  'date': datetime.datetime(2021, 3, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 13, 12, 57),
#  'latitude': -37.0316,
#  'longitude': 148.1519,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('6290c48da64bd56182400896'),
#  'climate': [{'GHI_w/m2': 149,
#               '_id': ObjectId('6290c48ca64bd561823ffd0b'),
#               'air_temperature_celcius': 19,
#               'date': datetime.datetime(2021, 3, 10, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 60.2,
#               'station': 948701,
#               'windspeed_knots': 6.4}],
#  'confidence': 55,
#  'date': datetime.datetime(2021, 3, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 10, 4, 43),
#  'latitude': -36.2544,
#  'longitude': 148.0353,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('6290c48da64bd56182400897'),
#  'climate': [{'GHI_w/m2': 149,
#               '_id': ObjectId('6290c48ca64bd561823ffd0b'),
#               'air_temperature_celcius': 19,
#               'date': datetime.datetime(2021, 3, 10, 0, 0),
#               'max_wind_speed': 12.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 60.2,
#               'station': 948701,
#               'windspeed_knots': 6.4}],
#  'confidence': 54,
#  'date': datetime.datetime(2021, 3, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 10, 4, 42, 30),
#  'latitude': -37.2197,
#  'longitude': 147.9621,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('6290c48da64bd5618240089a'),
#  'climate': [{'GHI_w/m2': 192,
#               '_id': ObjectId('6290c48ca64bd561823ffd0a'),
#               'air_temperature_celcius': 23,
#               'date': datetime.datetime(2021, 3, 9, 0, 0),
#               'max_wind_speed': 11.1,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 53.4,
#               'station': 948701,
#               'windspeed_knots': 6.1}],
#  'confidence': 54,
#  'date': datetime.datetime(2021, 3, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 9, 3, 57),
#  'latitude': -37.7171,
#  'longitude': 147.5866,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('6290c48da64bd5618240089c'),
#  'climate': [{'GHI_w/m2': 177,
#               '_id': ObjectId('6290c48ca64bd561823ffd09'),
#               'air_temperature_celcius': 21,
#               'date': datetime.datetime(2021, 3, 8, 0, 0),
#               'max_wind_speed': 13.0,
#               'precipitation ': 0.0,
#               'precipitation_type': 'I',
#               'relative_humidity': 51.7,
#               'station': 948701,
#               'windspeed_knots': 7.2}],
#  'confidence': 68,
#  'date': datetime.datetime(2021, 3, 8, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 8, 4, 51),
#  'latitude': -37.7885,
#  'longitude': 141.9352,
#  'surface_temperature_celcius': 55}

# %% [markdown]
# ##### h. Find the average surface temperature (°C) for each day. You are required to only display average surface temperature (°C) and the date in the output.

# %%
result = db.climate.aggregate([
    {
    "$lookup":{
        "from": "hotspot",
        "localField": "date",
        "foreignField": "date",
        "as":"hotspot",
        }
    },
    {"$project": {"_id":0,"date":1,"average_surface_temp":{"$avg":"$hotspot.surface_temperature_celcius"}}}
])
    
for x in result:
    pprint(x)
# Out:
# {'average_surface_temp': None, 'date': datetime.datetime(2020, 12, 31, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 3, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 4, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 5, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 6, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 7, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 8, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 9, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 11, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 12, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 13, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 14, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 15, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 17, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 21, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 22, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 23, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 25, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 28, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 30, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 31, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 1, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 3, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 4, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 5, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 6, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 7, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 8, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 9, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 11, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 12, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 13, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 14, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 15, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 17, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 21, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 22, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 23, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 25, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 2, 28, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 1, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 3, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 4, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 5, 0, 0)}
# {'average_surface_temp': 60.5, 'date': datetime.datetime(2021, 3, 6, 0, 0)}
# {'average_surface_temp': 64.0, 'date': datetime.datetime(2021, 3, 7, 0, 0)}
# {'average_surface_temp': 51.5, 'date': datetime.datetime(2021, 3, 8, 0, 0)}
# {'average_surface_temp': 46.666666666666664,
#  'date': datetime.datetime(2021, 3, 9, 0, 0)}
# {'average_surface_temp': 69.375, 'date': datetime.datetime(2021, 3, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 11, 0, 0)}
# {'average_surface_temp': 88.2, 'date': datetime.datetime(2021, 3, 12, 0, 0)}
# {'average_surface_temp': 38.5, 'date': datetime.datetime(2021, 3, 13, 0, 0)}
# {'average_surface_temp': 65.6, 'date': datetime.datetime(2021, 3, 14, 0, 0)}
# {'average_surface_temp': 46.0, 'date': datetime.datetime(2021, 3, 15, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 16, 0, 0)}
# {'average_surface_temp': 59.5, 'date': datetime.datetime(2021, 3, 17, 0, 0)}
# {'average_surface_temp': 79.33333333333333,
#  'date': datetime.datetime(2021, 3, 18, 0, 0)}
# {'average_surface_temp': 65.57142857142857,
#  'date': datetime.datetime(2021, 3, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 21, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 22, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 23, 0, 0)}
# {'average_surface_temp': 49.0, 'date': datetime.datetime(2021, 3, 24, 0, 0)}
# {'average_surface_temp': 66.0, 'date': datetime.datetime(2021, 3, 25, 0, 0)}
# {'average_surface_temp': 56.88235294117647,
#  'date': datetime.datetime(2021, 3, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 27, 0, 0)}
# {'average_surface_temp': 60.925925925925924,
#  'date': datetime.datetime(2021, 3, 28, 0, 0)}
# {'average_surface_temp': 51.0, 'date': datetime.datetime(2021, 3, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 3, 30, 0, 0)}
# {'average_surface_temp': 48.72727272727273,
#  'date': datetime.datetime(2021, 3, 31, 0, 0)}
# {'average_surface_temp': 46.714285714285715,
#  'date': datetime.datetime(2021, 4, 1, 0, 0)}
# {'average_surface_temp': 45.2, 'date': datetime.datetime(2021, 4, 2, 0, 0)}
# {'average_surface_temp': 58.44444444444444,
#  'date': datetime.datetime(2021, 4, 3, 0, 0)}
# {'average_surface_temp': 62.57303370786517,
#  'date': datetime.datetime(2021, 4, 4, 0, 0)}
# {'average_surface_temp': 53.142857142857146,
#  'date': datetime.datetime(2021, 4, 5, 0, 0)}
# {'average_surface_temp': 61.71186440677966,
#  'date': datetime.datetime(2021, 4, 6, 0, 0)}
# {'average_surface_temp': 50.69230769230769,
#  'date': datetime.datetime(2021, 4, 7, 0, 0)}
# {'average_surface_temp': 60.75, 'date': datetime.datetime(2021, 4, 8, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 4, 9, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 4, 10, 0, 0)}
# {'average_surface_temp': 46.291666666666664,
#  'date': datetime.datetime(2021, 4, 11, 0, 0)}
# {'average_surface_temp': 52.69565217391305,
#  'date': datetime.datetime(2021, 4, 12, 0, 0)}
# {'average_surface_temp': 58.57983193277311,
#  'date': datetime.datetime(2021, 4, 13, 0, 0)}
# {'average_surface_temp': 61.94444444444444,
#  'date': datetime.datetime(2021, 4, 14, 0, 0)}
# {'average_surface_temp': 59.57971014492754,
#  'date': datetime.datetime(2021, 4, 15, 0, 0)}
# {'average_surface_temp': 48.72222222222222,
#  'date': datetime.datetime(2021, 4, 16, 0, 0)}
# {'average_surface_temp': 50.921052631578945,
#  'date': datetime.datetime(2021, 4, 17, 0, 0)}
# {'average_surface_temp': 53.36615384615384,
#  'date': datetime.datetime(2021, 4, 18, 0, 0)}
# {'average_surface_temp': 54.16, 'date': datetime.datetime(2021, 4, 19, 0, 0)}
# {'average_surface_temp': 56.58064516129032,
#  'date': datetime.datetime(2021, 4, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 4, 21, 0, 0)}
# {'average_surface_temp': 54.5, 'date': datetime.datetime(2021, 4, 22, 0, 0)}
# {'average_surface_temp': 53.89473684210526,
#  'date': datetime.datetime(2021, 4, 23, 0, 0)}
# {'average_surface_temp': 59.375, 'date': datetime.datetime(2021, 4, 24, 0, 0)}
# {'average_surface_temp': 48.666666666666664,
#  'date': datetime.datetime(2021, 4, 25, 0, 0)}
# {'average_surface_temp': 34.0, 'date': datetime.datetime(2021, 4, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 4, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 4, 28, 0, 0)}
# {'average_surface_temp': 63.0, 'date': datetime.datetime(2021, 4, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 4, 30, 0, 0)}
# {'average_surface_temp': 68.4, 'date': datetime.datetime(2021, 5, 1, 0, 0)}
# {'average_surface_temp': 55.6, 'date': datetime.datetime(2021, 5, 2, 0, 0)}
# {'average_surface_temp': 56.796875, 'date': datetime.datetime(2021, 5, 3, 0, 0)}
# {'average_surface_temp': 56.80740740740741,
#  'date': datetime.datetime(2021, 5, 4, 0, 0)}
# {'average_surface_temp': 51.70967741935484,
#  'date': datetime.datetime(2021, 5, 5, 0, 0)}
# {'average_surface_temp': 57.529411764705884,
#  'date': datetime.datetime(2021, 5, 6, 0, 0)}
# {'average_surface_temp': 50.333333333333336,
#  'date': datetime.datetime(2021, 5, 7, 0, 0)}
# {'average_surface_temp': 56.291666666666664,
#  'date': datetime.datetime(2021, 5, 8, 0, 0)}
# {'average_surface_temp': 42.46153846153846,
#  'date': datetime.datetime(2021, 5, 9, 0, 0)}
# {'average_surface_temp': 52.86842105263158,
#  'date': datetime.datetime(2021, 5, 10, 0, 0)}
# {'average_surface_temp': 59.36842105263158,
#  'date': datetime.datetime(2021, 5, 11, 0, 0)}
# {'average_surface_temp': 51.5, 'date': datetime.datetime(2021, 5, 12, 0, 0)}
# {'average_surface_temp': 58.611111111111114,
#  'date': datetime.datetime(2021, 5, 13, 0, 0)}
# {'average_surface_temp': 49.0, 'date': datetime.datetime(2021, 5, 14, 0, 0)}
# {'average_surface_temp': 53.950980392156865,
#  'date': datetime.datetime(2021, 5, 15, 0, 0)}
# {'average_surface_temp': 39.666666666666664,
#  'date': datetime.datetime(2021, 5, 16, 0, 0)}
# {'average_surface_temp': 52.0, 'date': datetime.datetime(2021, 5, 17, 0, 0)}
# {'average_surface_temp': 44.142857142857146,
#  'date': datetime.datetime(2021, 5, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 21, 0, 0)}
# {'average_surface_temp': 54.484848484848484,
#  'date': datetime.datetime(2021, 5, 22, 0, 0)}
# {'average_surface_temp': 51.2, 'date': datetime.datetime(2021, 5, 23, 0, 0)}
# {'average_surface_temp': 40.333333333333336,
#  'date': datetime.datetime(2021, 5, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 25, 0, 0)}
# {'average_surface_temp': 49.5, 'date': datetime.datetime(2021, 5, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 28, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 30, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 5, 31, 0, 0)}
# {'average_surface_temp': 54.0, 'date': datetime.datetime(2021, 6, 1, 0, 0)}
# {'average_surface_temp': 47.72727272727273,
#  'date': datetime.datetime(2021, 6, 2, 0, 0)}
# {'average_surface_temp': 47.0, 'date': datetime.datetime(2021, 6, 3, 0, 0)}
# {'average_surface_temp': 52.22222222222222,
#  'date': datetime.datetime(2021, 6, 4, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 5, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 6, 0, 0)}
# {'average_surface_temp': 51.857142857142854,
#  'date': datetime.datetime(2021, 6, 7, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 8, 0, 0)}
# {'average_surface_temp': 49.0, 'date': datetime.datetime(2021, 6, 9, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 10, 0, 0)}
# {'average_surface_temp': 41.5, 'date': datetime.datetime(2021, 6, 11, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 12, 0, 0)}
# {'average_surface_temp': 41.0, 'date': datetime.datetime(2021, 6, 13, 0, 0)}
# {'average_surface_temp': 53.25, 'date': datetime.datetime(2021, 6, 14, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 15, 0, 0)}
# {'average_surface_temp': 42.5, 'date': datetime.datetime(2021, 6, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 17, 0, 0)}
# {'average_surface_temp': 42.0, 'date': datetime.datetime(2021, 6, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 19, 0, 0)}
# {'average_surface_temp': 71.16666666666667,
#  'date': datetime.datetime(2021, 6, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 21, 0, 0)}
# {'average_surface_temp': 46.0, 'date': datetime.datetime(2021, 6, 22, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 23, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 25, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 28, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 6, 29, 0, 0)}
# {'average_surface_temp': 44.333333333333336,
#  'date': datetime.datetime(2021, 6, 30, 0, 0)}
# {'average_surface_temp': 30.5, 'date': datetime.datetime(2021, 7, 1, 0, 0)}
# {'average_surface_temp': 43.5, 'date': datetime.datetime(2021, 7, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 3, 0, 0)}
# {'average_surface_temp': 40.0, 'date': datetime.datetime(2021, 7, 4, 0, 0)}
# {'average_surface_temp': 45.0, 'date': datetime.datetime(2021, 7, 5, 0, 0)}
# {'average_surface_temp': 56.0, 'date': datetime.datetime(2021, 7, 6, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 7, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 8, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 9, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 11, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 12, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 13, 0, 0)}
# {'average_surface_temp': 41.5, 'date': datetime.datetime(2021, 7, 14, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 15, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 17, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 21, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 22, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 23, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 25, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 28, 0, 0)}
# {'average_surface_temp': 48.0, 'date': datetime.datetime(2021, 7, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 7, 30, 0, 0)}
# {'average_surface_temp': 47.0, 'date': datetime.datetime(2021, 7, 31, 0, 0)}
# {'average_surface_temp': 58.0, 'date': datetime.datetime(2021, 8, 1, 0, 0)}
# {'average_surface_temp': 63.5, 'date': datetime.datetime(2021, 8, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 3, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 4, 0, 0)}
# {'average_surface_temp': 40.0, 'date': datetime.datetime(2021, 8, 5, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 6, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 7, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 8, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 9, 0, 0)}
# {'average_surface_temp': 63.0, 'date': datetime.datetime(2021, 8, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 11, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 12, 0, 0)}
# {'average_surface_temp': 49.0, 'date': datetime.datetime(2021, 8, 13, 0, 0)}
# {'average_surface_temp': 40.8, 'date': datetime.datetime(2021, 8, 14, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 15, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 17, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 20, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 21, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 22, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 23, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 25, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 28, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 30, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 8, 31, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 1, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 3, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 4, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 5, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 6, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 7, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 8, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 9, 0, 0)}
# {'average_surface_temp': 56.5, 'date': datetime.datetime(2021, 9, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 11, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 12, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 13, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 14, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 15, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 17, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 19, 0, 0)}
# {'average_surface_temp': 63.6, 'date': datetime.datetime(2021, 9, 20, 0, 0)}
# {'average_surface_temp': 40.5, 'date': datetime.datetime(2021, 9, 21, 0, 0)}
# {'average_surface_temp': 45.0, 'date': datetime.datetime(2021, 9, 22, 0, 0)}
# {'average_surface_temp': 52.73913043478261,
#  'date': datetime.datetime(2021, 9, 23, 0, 0)}
# {'average_surface_temp': 53.57142857142857,
#  'date': datetime.datetime(2021, 9, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 25, 0, 0)}
# {'average_surface_temp': 33.0, 'date': datetime.datetime(2021, 9, 26, 0, 0)}
# {'average_surface_temp': 49.714285714285715,
#  'date': datetime.datetime(2021, 9, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 28, 0, 0)}
# {'average_surface_temp': 43.0, 'date': datetime.datetime(2021, 9, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 9, 30, 0, 0)}
# {'average_surface_temp': 48.25, 'date': datetime.datetime(2021, 10, 1, 0, 0)}
# {'average_surface_temp': 43.57142857142857,
#  'date': datetime.datetime(2021, 10, 2, 0, 0)}
# {'average_surface_temp': 50.0, 'date': datetime.datetime(2021, 10, 3, 0, 0)}
# {'average_surface_temp': 49.0, 'date': datetime.datetime(2021, 10, 4, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 5, 0, 0)}
# {'average_surface_temp': 44.0, 'date': datetime.datetime(2021, 10, 6, 0, 0)}
# {'average_surface_temp': 42.0, 'date': datetime.datetime(2021, 10, 7, 0, 0)}
# {'average_surface_temp': 41.0, 'date': datetime.datetime(2021, 10, 8, 0, 0)}
# {'average_surface_temp': 44.0, 'date': datetime.datetime(2021, 10, 9, 0, 0)}
# {'average_surface_temp': 53.333333333333336,
#  'date': datetime.datetime(2021, 10, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 11, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 12, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 13, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 14, 0, 0)}
# {'average_surface_temp': 72.66666666666667,
#  'date': datetime.datetime(2021, 10, 15, 0, 0)}
# {'average_surface_temp': 36.0, 'date': datetime.datetime(2021, 10, 16, 0, 0)}
# {'average_surface_temp': 51.6, 'date': datetime.datetime(2021, 10, 17, 0, 0)}
# {'average_surface_temp': 52.166666666666664,
#  'date': datetime.datetime(2021, 10, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 19, 0, 0)}
# {'average_surface_temp': 50.0, 'date': datetime.datetime(2021, 10, 20, 0, 0)}
# {'average_surface_temp': 51.25, 'date': datetime.datetime(2021, 10, 21, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 22, 0, 0)}
# {'average_surface_temp': 38.0, 'date': datetime.datetime(2021, 10, 23, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 25, 0, 0)}
# {'average_surface_temp': 44.6, 'date': datetime.datetime(2021, 10, 26, 0, 0)}
# {'average_surface_temp': 50.4, 'date': datetime.datetime(2021, 10, 27, 0, 0)}
# {'average_surface_temp': 56.0, 'date': datetime.datetime(2021, 10, 28, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 30, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 10, 31, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 1, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 3, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 4, 0, 0)}
# {'average_surface_temp': 58.5, 'date': datetime.datetime(2021, 11, 5, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 6, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 7, 0, 0)}
# {'average_surface_temp': 45.5, 'date': datetime.datetime(2021, 11, 8, 0, 0)}
# {'average_surface_temp': 61.3, 'date': datetime.datetime(2021, 11, 9, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 10, 0, 0)}
# {'average_surface_temp': 46.25, 'date': datetime.datetime(2021, 11, 11, 0, 0)}
# {'average_surface_temp': 53.0, 'date': datetime.datetime(2021, 11, 12, 0, 0)}
# {'average_surface_temp': 47.0, 'date': datetime.datetime(2021, 11, 13, 0, 0)}
# {'average_surface_temp': 52.0, 'date': datetime.datetime(2021, 11, 14, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 15, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 17, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 20, 0, 0)}
# {'average_surface_temp': 59.0, 'date': datetime.datetime(2021, 11, 21, 0, 0)}
# {'average_surface_temp': 61.5, 'date': datetime.datetime(2021, 11, 22, 0, 0)}
# {'average_surface_temp': 58.8, 'date': datetime.datetime(2021, 11, 23, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 24, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 25, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 26, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 11, 27, 0, 0)}
# {'average_surface_temp': 42.0, 'date': datetime.datetime(2021, 11, 28, 0, 0)}
# {'average_surface_temp': 60.625, 'date': datetime.datetime(2021, 11, 29, 0, 0)}
# {'average_surface_temp': 52.41935483870968,
#  'date': datetime.datetime(2021, 11, 30, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 1, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 2, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 3, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 4, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 5, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 6, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 7, 0, 0)}
# {'average_surface_temp': 50.6, 'date': datetime.datetime(2021, 12, 8, 0, 0)}
# {'average_surface_temp': 58.25, 'date': datetime.datetime(2021, 12, 9, 0, 0)}
# {'average_surface_temp': 46.0, 'date': datetime.datetime(2021, 12, 10, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 11, 0, 0)}
# {'average_surface_temp': 44.0, 'date': datetime.datetime(2021, 12, 12, 0, 0)}
# {'average_surface_temp': 60.0, 'date': datetime.datetime(2021, 12, 13, 0, 0)}
# {'average_surface_temp': 70.0, 'date': datetime.datetime(2021, 12, 14, 0, 0)}
# {'average_surface_temp': 39.0, 'date': datetime.datetime(2021, 12, 15, 0, 0)}
# {'average_surface_temp': 57.8, 'date': datetime.datetime(2021, 12, 16, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 17, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 18, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 19, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 20, 0, 0)}
# {'average_surface_temp': 46.0, 'date': datetime.datetime(2021, 12, 21, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 22, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 23, 0, 0)}
# {'average_surface_temp': 32.0, 'date': datetime.datetime(2021, 12, 24, 0, 0)}
# {'average_surface_temp': 54.0, 'date': datetime.datetime(2021, 12, 25, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 26, 0, 0)}
# {'average_surface_temp': 62.75, 'date': datetime.datetime(2021, 12, 27, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 28, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 29, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 30, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 12, 31, 0, 0)}
# {'average_surface_temp': None, 'date': datetime.datetime(2021, 1, 1, 0, 0)}

# %% [markdown]
# ##### i. Find the top 10 records with the lowest GHI.

# %%
results = climate_collection.aggregate([
    {"$limit": 10},
    {"$sort": {"GHI_w/m2":1}},
    {"$lookup":
    {
        "from": "hotspot",
        "localField": "date",
        "foreignField": "date",
        "as":"hotspot",
    }}])
for x in results:
    pprint(x)
# Out:
# {'GHI_w/m2': 128,
#  '_id': ObjectId('6290c48ca64bd561823ffcc8'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2021, 1, 2, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': 0.02,
#  'precipitation_type': 'G',
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('6290c48ca64bd561823ffcc9'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2021, 1, 3, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': 0.0,
#  'precipitation_type': 'G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6290c48ca64bd561823ffcc7'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2020, 12, 31, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6290c48ca64bd561823ffccf'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 1, 9, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 8.9,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('6290c48ca64bd561823ffcce'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2021, 1, 8, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6290c48ca64bd561823ffcd0'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2021, 1, 10, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('6290c48ca64bd561823ffccb'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2021, 1, 5, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('6290c48ca64bd561823ffcca'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2021, 1, 4, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('6290c48ca64bd561823ffccc'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2021, 1, 6, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('6290c48ca64bd561823ffccd'),
#  'air_temperature_celcius': 32,
#  'date': datetime.datetime(2021, 1, 7, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}

# %% [markdown]
# ##### j. Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.

# %%
result = db.climate.aggregate([{
    "$lookup":
    {
        "from": "hotspot",
        "localField": "date",
        "foreignField": "date",
        "as":"hotspot",
    }},
    {
    "$match" : {"precipitation_type": "G", "precipitation ": {"$gte": 0.20, "$lte": 0.35}}
    }])
for x in result:
    pprint(x)
# pprint([x for x in result])
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('6290c48ca64bd561823ffcd3'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 1, 13, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('6290c48ca64bd561823ffd1e'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2021, 3, 29, 0, 0),
#  'hotspot': [{'_id': ObjectId('6290c48da64bd56182400804'),
#               'confidence': 69,
#               'date': datetime.datetime(2021, 3, 29, 0, 0),
#               'datetime': datetime.datetime(2021, 3, 29, 0, 48, 40),
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51}],
#  'max_wind_speed': 21.0,
#  'precipitation ': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('6290c48ca64bd561823ffd34'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2021, 4, 20, 0, 0),
#  'hotspot': [{'_id': ObjectId('6290c48da64bd56182400278'),
#               'confidence': 84,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 44, 20),
#               'latitude': -36.8871,
#               'longitude': 145.1536,
#               'surface_temperature_celcius': 58},
#              {'_id': ObjectId('6290c48da64bd56182400279'),
#               'confidence': 59,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 36),
#               'latitude': -38.4685,
#               'longitude': 146.673,
#               'surface_temperature_celcius': 40},
#              {'_id': ObjectId('6290c48da64bd5618240027a'),
#               'confidence': 60,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 34, 10),
#               'latitude': -36.8922,
#               'longitude': 145.1252,
#               'surface_temperature_celcius': 40},
#              {'_id': ObjectId('6290c48da64bd5618240027b'),
#               'confidence': 93,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 34, 10),
#               'latitude': -37.769,
#               'longitude': 147.94,
#               'surface_temperature_celcius': 72},
#              {'_id': ObjectId('6290c48da64bd5618240027c'),
#               'confidence': 77,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 33, 40),
#               'latitude': -36.0799,
#               'longitude': 146.0784,
#               'surface_temperature_celcius': 50},
#              {'_id': ObjectId('6290c48da64bd5618240027d'),
#               'confidence': 88,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 33, 20),
#               'latitude': -36.0829,
#               'longitude': 146.0621,
#               'surface_temperature_celcius': 63},
#              {'_id': ObjectId('6290c48da64bd5618240027e'),
#               'confidence': 90,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 50),
#               'latitude': -36.1303,
#               'longitude': 146.3606,
#               'surface_temperature_celcius': 67},
#              {'_id': ObjectId('6290c48da64bd5618240027f'),
#               'confidence': 67,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 50),
#               'latitude': -37.7615,
#               'longitude': 147.9169,
#               'surface_temperature_celcius': 45},
#              {'_id': ObjectId('6290c48da64bd56182400280'),
#               'confidence': 63,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.8079,
#               'longitude': 145.1409,
#               'surface_temperature_celcius': 42},
#              {'_id': ObjectId('6290c48da64bd56182400281'),
#               'confidence': 85,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -37.7783,
#               'longitude': 147.9284,
#               'surface_temperature_celcius': 60},
#              {'_id': ObjectId('6290c48da64bd56182400282'),
#               'confidence': 79,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.8846,
#               'longitude': 145.1679,
#               'surface_temperature_celcius': 52},
#              {'_id': ObjectId('6290c48da64bd56182400283'),
#               'confidence': 80,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -37.2341,
#               'longitude': 149.1736,
#               'surface_temperature_celcius': 53},
#              {'_id': ObjectId('6290c48da64bd56182400284'),
#               'confidence': 63,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.9189,
#               'longitude': 147.5603,
#               'surface_temperature_celcius': 52},
#              {'_id': ObjectId('6290c48da64bd56182400285'),
#               'confidence': 98,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.1345,
#               'longitude': 146.351,
#               'surface_temperature_celcius': 84},
#              {'_id': ObjectId('6290c48da64bd56182400286'),
#               'confidence': 87,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.9246,
#               'longitude': 147.5559,
#               'surface_temperature_celcius': 62},
#              {'_id': ObjectId('6290c48da64bd56182400287'),
#               'confidence': 64,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 19),
#               'latitude': -36.085,
#               'longitude': 145.9096,
#               'surface_temperature_celcius': 42},
#              {'_id': ObjectId('6290c48da64bd56182400288'),
#               'confidence': 88,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 18, 40),
#               'latitude': -38.1301,
#               'longitude': 143.9398,
#               'surface_temperature_celcius': 63},
#              {'_id': ObjectId('6290c48da64bd56182400289'),
#               'confidence': 69,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 18, 20),
#               'latitude': -37.7087,
#               'longitude': 145.5499,
#               'surface_temperature_celcius': 45},
#              {'_id': ObjectId('6290c48da64bd5618240028a'),
#               'confidence': 100,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 18, 20),
#               'latitude': -36.5865,
#               'longitude': 145.2081,
#               'surface_temperature_celcius': 111},
#              {'_id': ObjectId('6290c48da64bd5618240028b'),
#               'confidence': 73,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 17, 10),
#               'latitude': -36.8702,
#               'longitude': 144.0381,
#               'surface_temperature_celcius': 47},
#              {'_id': ObjectId('6290c48da64bd5618240028c'),
#               'confidence': 99,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 17, 10),
#               'latitude': -36.1586,
#               'longitude': 145.6666,
#               'surface_temperature_celcius': 85},
#              {'_id': ObjectId('6290c48da64bd5618240028d'),
#               'confidence': 74,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 16, 50),
#               'latitude': -37.8672,
#               'longitude': 143.8194,
#               'surface_temperature_celcius': 48},
#              {'_id': ObjectId('6290c48da64bd5618240028e'),
#               'confidence': 78,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 15, 30),
#               'latitude': -36.5956,
#               'longitude': 145.20600000000002,
#               'surface_temperature_celcius': 51},
#              {'_id': ObjectId('6290c48da64bd5618240028f'),
#               'confidence': 77,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 14, 20),
#               'latitude': -37.2197,
#               'longitude': 148.8134,
#               'surface_temperature_celcius': 50},
#              {'_id': ObjectId('6290c48da64bd56182400290'),
#               'confidence': 96,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 14, 10),
#               'latitude': -36.5847,
#               'longitude': 145.1968,
#               'surface_temperature_celcius': 78},
#              {'_id': ObjectId('6290c48da64bd56182400291'),
#               'confidence': 89,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13, 40),
#               'latitude': -37.6997,
#               'longitude': 145.5519,
#               'surface_temperature_celcius': 64},
#              {'_id': ObjectId('6290c48da64bd56182400292'),
#               'confidence': 61,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13, 30),
#               'latitude': -37.931999999999995,
#               'longitude': 146.1845,
#               'surface_temperature_celcius': 50},
#              {'_id': ObjectId('6290c48da64bd56182400293'),
#               'confidence': 76,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13, 10),
#               'latitude': -36.6407,
#               'longitude': 144.2957,
#               'surface_temperature_celcius': 50},
#              {'_id': ObjectId('6290c48da64bd56182400294'),
#               'confidence': 63,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13),
#               'latitude': -36.1569,
#               'longitude': 145.6554,
#               'surface_temperature_celcius': 41},
#              {'_id': ObjectId('6290c48da64bd56182400295'),
#               'confidence': 54,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13),
#               'latitude': -36.6363,
#               'longitude': 144.3033,
#               'surface_temperature_celcius': 40},
#              {'_id': ObjectId('6290c48da64bd56182400296'),
#               'confidence': 76,
#               'date': datetime.datetime(2021, 4, 20, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 20, 0, 12, 50),
#               'latitude': -37.2212,
#               'longitude': 148.8262,
#               'surface_temperature_celcius': 49}],
#  'max_wind_speed': 15.9,
#  'precipitation ': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('6290c48ca64bd561823ffd3a'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 4, 26, 0, 0),
#  'hotspot': [{'_id': ObjectId('6290c48da64bd56182400257'),
#               'confidence': 56,
#               'date': datetime.datetime(2021, 4, 26, 0, 0),
#               'datetime': datetime.datetime(2021, 4, 26, 13, 26, 10),
#               'latitude': -36.5511,
#               'longitude': 146.7819,
#               'surface_temperature_celcius': 34}],
#  'max_wind_speed': 20.0,
#  'precipitation ': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('6290c48ca64bd561823ffd59'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2021, 5, 27, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': 0.35,
#  'precipitation_type': 'G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('6290c48ca64bd561823ffd5c'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2021, 5, 30, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('6290c48ca64bd561823ffd7e'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 7, 3, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('6290c48ca64bd561823ffd96'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 7, 27, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 21.0,
#  'precipitation ': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('6290c48ca64bd561823ffda0'),
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2021, 8, 6, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('6290c48ca64bd561823ffdb4'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 8, 26, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  '_id': ObjectId('6290c48ca64bd561823ffdbe'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2021, 9, 5, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('6290c48ca64bd561823ffdc0'),
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2021, 9, 7, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('6290c48ca64bd561823ffdc8'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 9, 15, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('6290c48ca64bd561823ffddc'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2021, 10, 5, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('6290c48ca64bd561823ffdf4'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2021, 10, 29, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 27.0,
#  'precipitation ': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('6290c48ca64bd561823ffdf5'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 10, 30, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('6290c48ca64bd561823ffe06'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2021, 11, 16, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('6290c48ca64bd561823ffe07'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 11, 17, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6290c48ca64bd561823ffe14'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'hotspot': [{'_id': ObjectId('6290c48da64bd561823ffe5d'),
#               'confidence': 52,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 23, 25, 57),
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47},
#              {'_id': ObjectId('6290c48da64bd561823ffe5e'),
#               'confidence': 100,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#               'latitude': -37.591,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 53},
#              {'_id': ObjectId('6290c48da64bd561823ffe5f'),
#               'confidence': 51,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42},
#              {'_id': ObjectId('6290c48da64bd561823ffe60'),
#               'confidence': 64,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42},
#              {'_id': ObjectId('6290c48da64bd561823ffe61'),
#               'confidence': 100,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#               'latitude': -37.585,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 54},
#              {'_id': ObjectId('6290c48da64bd561823ffe62'),
#               'confidence': 69,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#               'latitude': -37.58,
#               'longitude': 149.33100000000002,
#               'surface_temperature_celcius': 35},
#              {'_id': ObjectId('6290c48da64bd561823ffe63'),
#               'confidence': 100,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#               'latitude': -37.583,
#               'longitude': 149.316,
#               'surface_temperature_celcius': 49},
#              {'_id': ObjectId('6290c48da64bd561823ffe64'),
#               'confidence': 61,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 32),
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31},
#              {'_id': ObjectId('6290c48da64bd561823ffe65'),
#               'confidence': 62,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33},
#              {'_id': ObjectId('6290c48da64bd561823ffe66'),
#               'confidence': 64,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32},
#              {'_id': ObjectId('6290c48da64bd561823ffe67'),
#               'confidence': 84,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.596,
#               'longitude': 149.319,
#               'surface_temperature_celcius': 38},
#              {'_id': ObjectId('6290c48da64bd561823ffe68'),
#               'confidence': 81,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.63,
#               'longitude': 149.232,
#               'surface_temperature_celcius': 42},
#              {'_id': ObjectId('6290c48da64bd561823ffe69'),
#               'confidence': 100,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.644,
#               'longitude': 149.233,
#               'surface_temperature_celcius': 55},
#              {'_id': ObjectId('6290c48da64bd561823ffe6a'),
#               'confidence': 100,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.641999999999996,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65},
#              {'_id': ObjectId('6290c48da64bd561823ffe6b'),
#               'confidence': 100,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 14),
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71},
#              {'_id': ObjectId('6290c48da64bd561823ffe6c'),
#               'confidence': 84,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 4, 35),
#               'latitude': -37.384,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 59},
#              {'_id': ObjectId('6290c48da64bd561823ffe6d'),
#               'confidence': 73,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 4, 35),
#               'latitude': -37.389,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 50},
#              {'_id': ObjectId('6290c48da64bd561823ffe6e'),
#               'confidence': 98,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.605,
#               'longitude': 149.30200000000002,
#               'surface_temperature_celcius': 83},
#              {'_id': ObjectId('6290c48da64bd561823ffe6f'),
#               'confidence': 81,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.626999999999995,
#               'longitude': 149.261,
#               'surface_temperature_celcius': 57},
#              {'_id': ObjectId('6290c48da64bd561823ffe70'),
#               'confidence': 84,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.623000000000005,
#               'longitude': 149.284,
#               'surface_temperature_celcius': 61},
#              {'_id': ObjectId('6290c48da64bd561823ffe71'),
#               'confidence': 99,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86},
#              {'_id': ObjectId('6290c48da64bd561823ffe72'),
#               'confidence': 69,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48},
#              {'_id': ObjectId('6290c48da64bd561823ffe73'),
#               'confidence': 60,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 21),
#               'latitude': -37.637,
#               'longitude': 146.28799999999998,
#               'surface_temperature_celcius': 42},
#              {'_id': ObjectId('6290c48da64bd561823ffe74'),
#               'confidence': 83,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.608000000000004,
#               'longitude': 149.282,
#               'surface_temperature_celcius': 58},
#              {'_id': ObjectId('6290c48da64bd561823ffe75'),
#               'confidence': 87,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.62,
#               'longitude': 149.29399999999998,
#               'surface_temperature_celcius': 63},
#              {'_id': ObjectId('6290c48da64bd561823ffe76'),
#               'confidence': 95,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76},
#              {'_id': ObjectId('6290c48da64bd561823ffe77'),
#               'confidence': 81,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.61,
#               'longitude': 149.296,
#               'surface_temperature_celcius': 56},
#              {'_id': ObjectId('6290c48da64bd561823ffe78'),
#               'confidence': 73,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.603,
#               'longitude': 149.32399999999998,
#               'surface_temperature_celcius': 51},
#              {'_id': ObjectId('6290c48da64bd561823ffe79'),
#               'confidence': 81,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.602,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 55},
#              {'_id': ObjectId('6290c48da64bd561823ffe7a'),
#               'confidence': 69,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50},
#              {'_id': ObjectId('6290c48da64bd561823ffe7b'),
#               'confidence': 64,
#               'date': datetime.datetime(2021, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 49),
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41}],
#  'max_wind_speed': 15.0,
#  'precipitation ': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
